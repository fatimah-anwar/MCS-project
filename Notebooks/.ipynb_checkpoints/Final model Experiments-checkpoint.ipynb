# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import random
import networkx as nx   

sns.set(style="whitegrid")

import sys
sys.path.append('../Final_model')
from model import myModel
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %% [markdown]
# ## Experiment 1: Impact of 2 sources of information (online communication + offline observations)
#
#
# ### 1. Mobilty rate over time for different alpha values
# - Baseline: alpha = 0.5
# - alpha values: [0, 0.2, 0.4, 0.6, 0.8, 1]
# - all simulations will use the same initialization for the agents attributes
# - Online network: complete graph
# - Simulation diruation : 100 time step (similar to the replicated model)

# %%
num_steps = 100
n = 500

# %%
model = myModel(N = n, w = 5 , h = 5)

# %%
### alpha = 1 (no offline data)
# model = myModel(N = n, w = 5 , h = 5)

model.reinitialize_agents()
model.set_alpha(1)

for _ in range(num_steps):
    model.step()

model_data = model.datacollector.get_model_vars_dataframe()

alpha_1_decisions = list(model_data['mobility_rate'])
alpha_1_perception = list(model_data['combined_info_avg'])
alpha_1_op = list(model_data['op_avg']) 

alpha_1_start_move = list(model_data['start_moving_rate'])
alpha_1_stop_move = list(model_data['stop_moving_rate']) 
alpha_1_all_update = list(model_data['updated_decision_rate'])

# %%
### alpha = 0.8
# model = myModel(N = n, w = 5 , h = 5)

model.reinitialize_agents()
model.set_alpha(0.8)

for _ in range(num_steps):
    model.step()

model_data = model.datacollector.get_model_vars_dataframe()

alpha_08_decisions = list(model_data['mobility_rate'])
alpha_08_perception = list(model_data['combined_info_avg'])
alpha_08_op = list(model_data['op_avg']) 

alpha_08_start_move = list(model_data['start_moving_rate'])
alpha_08_stop_move = list(model_data['stop_moving_rate']) 
alpha_08_all_update = list(model_data['updated_decision_rate'])

# %%
# ### alpha = 0.6
# # model = myModel(N = n, w = 5 , h = 5)

# model.reinitialize_agents()
# model.set_alpha(0.6)

# for _ in range(num_steps):
#     model.step()
    
# model_data = model.datacollector.get_model_vars_dataframe()

# alpha_06_decisions = list(model_data['mobility_rate'])
# alpha_06_perception = list(model_data['combined_info_avg'])
# alpha_06_op = list(model_data['op_avg'])

# %%
### alpha = 0.5
# model = myModel(N = n, w = 5 , h = 5)

model.reinitialize_agents()
model.set_alpha(0.5)

for _ in range(num_steps):
    model.step()
    
model_data = model.datacollector.get_model_vars_dataframe()

alpha_05_decisions = list(model_data['mobility_rate'])
alpha_05_perception = list(model_data['combined_info_avg']) 
alpha_05_op = list(model_data['op_avg']) 

alpha_05_start_move = list(model_data['start_moving_rate'])
alpha_05_stop_move = list(model_data['stop_moving_rate']) 
alpha_05_all_update = list(model_data['updated_decision_rate'])

# %%
# ### alpha = 0.4 
# # model = myModel(N = n, w = 5 , h = 5)

# model.reinitialize_agents()
# model.set_alpha(0.4)

# for _ in range(num_steps):
#     model.step()

# model_data = model.datacollector.get_model_vars_dataframe()

# alpha_04_decisions = list(model_data['mobility_rate'])
# alpha_04_perception = list(model_data['combined_info_avg'])
# alpha_04_op = list(model_data['op_avg'])

# %%
### alpha = 0.2 
# model = myModel(N = n, w = 5 , h = 5)

model.reinitialize_agents()
model.set_alpha(0.2)

for _ in range(num_steps):
    model.step()

model_data = model.datacollector.get_model_vars_dataframe()

alpha_02_decisions = list(model_data['mobility_rate'])
alpha_02_perception = list(model_data['combined_info_avg'])
alpha_02_op = list(model_data['op_avg'])

alpha_02_start_move = list(model_data['start_moving_rate'])
alpha_02_stop_move = list(model_data['stop_moving_rate']) 
alpha_02_all_update = list(model_data['updated_decision_rate'])

# %%
### alpha = 0 (no online data) 
# model = myModel(N = n, w = 5 , h = 5)

model.reinitialize_agents()
model.set_alpha(0)

for _ in range(num_steps):
    model.step()
    
model_data = model.datacollector.get_model_vars_dataframe()

alpha_0_decisions = list(model_data['mobility_rate'])
alpha_0_perception = list(model_data['combined_info_avg'])
alpha_0_op = list(model_data['op_avg']) 

alpha_0_start_move = list(model_data['start_moving_rate'])
alpha_0_stop_move = list(model_data['stop_moving_rate']) 
alpha_0_all_update = list(model_data['updated_decision_rate'])

# %% [markdown]
# ### results

# %%
plt.figure(figsize=(5,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

x_values = list(range(num_steps))

sns.lineplot(x = x_values , y = alpha_0_decisions , label = "0") 
sns.lineplot(x = x_values , y = alpha_02_decisions , label = "0.2") 
# sns.lineplot(x = x_values , y = alpha_04_decisions , label = "0.4") 

sns.lineplot(x = x_values , y = alpha_05_decisions , label = "0.5")  #baseline

# sns.lineplot(x = x_values , y = alpha_06_decisions , label = "0.6") 
sns.lineplot(x = x_values , y = alpha_08_decisions , label = "0.8") 
sns.lineplot(x = x_values , y = alpha_1_decisions , label = "1") 


plt.ylim(0,1)
plt.xlabel("Time step")
plt.ylabel("Mobility rate")
plt.legend(title = "alpha", bbox_to_anchor=(1, 1), ncol=1)

plt.show()

# %%
plt.figure(figsize=(5,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

x_values = list(range(num_steps))

sns.lineplot(x = x_values , y = alpha_0_op , label = "0") 
sns.lineplot(x = x_values , y = alpha_02_op , label = "0.2") 
# sns.lineplot(x = x_values , y = alpha_04_op , label = "0.4") 

sns.lineplot(x = x_values , y = alpha_05_op , label = "0.5")  #baseline

# sns.lineplot(x = x_values , y = alpha_06_op , label = "0.6") 
sns.lineplot(x = x_values , y = alpha_08_op , label = "0.8") 
sns.lineplot(x = x_values , y = alpha_1_op , label = "1") 


plt.ylim(0,1)
plt.xlabel("Time step")
plt.ylabel("Collective risk perception")
plt.legend(title = "alpha", bbox_to_anchor=(1, 1), ncol=1)

plt.show()

# %% [markdown]
# ### 2. Mobilty update ratio

# %%
plt.figure(figsize=(5,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

x_values = list(range(num_steps))


sns.lineplot(x = x_values , y = alpha_0_all_update , label = "0")
sns.lineplot(x = x_values , y = alpha_02_all_update , label = "0.2")
sns.lineplot(x = x_values , y = alpha_05_all_update , label = "0.5")
sns.lineplot(x = x_values , y = alpha_08_all_update , label = "0.8")
sns.lineplot(x = x_values , y = alpha_1_all_update , label = "1")  



# plt.ylim(0,1)
plt.xlabel("Time step")
plt.ylabel("")
plt.legend(title = "alpha", bbox_to_anchor=(1, 1), ncol=1)

plt.show()

# %%
plt.figure(figsize=(5,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

x_values = list(range(num_steps))

sns.lineplot(x = x_values , y = alpha_0_start_move , label = "0")
# sns.lineplot(x = x_values , y = alpha_02_start_move , label = "0.2")  
sns.lineplot(x = x_values , y = alpha_05_start_move , label = "0.5")  
# sns.lineplot(x = x_values , y = alpha_08_start_move , label = "0.8")  
sns.lineplot(x = x_values , y = alpha_1_start_move , label = "1")  


# plt.ylim(0,1)
plt.xlabel("Time step")
plt.ylabel("")
plt.legend(title = "alpha", bbox_to_anchor=(1, 1), ncol=1)

plt.show()

# %%
plt.figure(figsize=(5,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

x_values = list(range(num_steps))

sns.lineplot(x = x_values , y = alpha_0_stop_move , label = "0")
# sns.lineplot(x = x_values , y = alpha_02_stop_move , label = "0.2")  
sns.lineplot(x = x_values , y = alpha_05_stop_move , label = "0.5")  
# sns.lineplot(x = x_values , y = alpha_08_stop_move , label = "0.8")  
sns.lineplot(x = x_values , y = alpha_1_stop_move , label = "1")  


# plt.ylim(0,1)
plt.xlabel("Time step")
plt.ylabel("")
plt.legend(title = "alpha", bbox_to_anchor=(1, 1), ncol=1)

plt.show()

# %% [markdown]
# ### 3. relation between mobility data and other attributes:

# %%
num_steps = 100
n = 500
w = 5
h = 5

# %%
model = myModel(N = n, w = w , h = h)

# %%
model.reinitialize_agents()
model.set_alpha(0.5)

for _ in range(num_steps):
    model.step()
    
model_data = model.datacollector.get_model_vars_dataframe()
agents_data = model.datacollector.get_agent_vars_dataframe()

# %%
agents_data['decision_update_count'] = (agents_data['move_counter'] + agents_data['stop_move_counter']) 
agents_data['decision_update_rate'] = agents_data['decision_update_count'] / num_steps

# %%
plt.figure(figsize=(5,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

x1 = list(agents_data.tail(n).query("decision == 0")['decision_th'])
y1 = list(agents_data.tail(n).query("decision == 0")['decision_update_rate'])

x2 = list(agents_data.tail(n).query("decision == 1")['decision_th'])
y2 = list(agents_data.tail(n).query("decision == 1")['decision_update_rate'])

plt.scatter(x1, y1, marker='o', s = 30, alpha = 0.1, color="blue" ,label = "0")
plt.scatter(x2, y2, marker='o', s = 30, alpha = 0.1, color="red" ,label = "1")


plt.xlabel('decision_th')
plt.ylabel('decision_update_rate')
plt.legend(title = "decision", bbox_to_anchor=(1, 1), ncol=1)

plt.show()

# %%
plt.figure(figsize=(5,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 
    

x1 = list(agents_data.tail(n).query("decision == 0")['decision_th'])
y1 = list(agents_data.tail(n).query("decision == 0")['opinion'])

x2 = list(agents_data.tail(n).query("decision == 1")['decision_th'])
y2 = list(agents_data.tail(n).query("decision == 1")['opinion'])


plt.scatter(x1, y1, marker='o', s = 30, alpha = 0.1, color="blue" ,label = "0")
plt.scatter(x2, y2, marker='o', s = 30, alpha = 0.1, color="red" ,label = "1")


plt.xlabel('decision_th')
plt.ylabel('opinion')
plt.legend(title = "decision", bbox_to_anchor=(1, 1), ncol=1)

plt.show()

# %%
plt.figure(figsize=(5,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

x1 = []
x2 = []

for i in range(n):
    if list(agents_data.query(f"AgentID == {i}").tail(1)['decision'])[0] == 0:
        x1.append(model.agents_initial_opinions[i])
    else:
        x2.append(model.agents_initial_opinions[i])

y1 = list(agents_data.tail(n).query("decision == 0")['opinion'])
y2 = list(agents_data.tail(n).query("decision == 1")['opinion'])


plt.scatter(x1, y1, marker='o', s = 30, alpha = 0.1, color="blue" ,label = "0")
plt.scatter(x2, y2, marker='o', s = 30, alpha = 0.1, color="red" ,label = "1")


plt.xlabel('inital opinion')
plt.ylabel('final opinion')
plt.legend(title = "decision", bbox_to_anchor=(1, 1), ncol=1)

plt.show()

# %%
model.reinitialize_agents()
model.set_alpha(0)

for _ in range(num_steps):
    model.step()
    
model_data = model.datacollector.get_model_vars_dataframe()
agents_data = model.datacollector.get_agent_vars_dataframe()

# %%
agents_data['decision_update_count'] = (agents_data['move_counter'] + agents_data['stop_move_counter']) 
agents_data['decision_update_rate'] = agents_data['decision_update_count'] / num_steps

# %%
plt.figure(figsize=(5,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

x1 = list(agents_data.tail(n).query("decision == 0")['decision_th'])
y1 = list(agents_data.tail(n).query("decision == 0")['decision_update_rate'])

x2 = list(agents_data.tail(n).query("decision == 1")['decision_th'])
y2 = list(agents_data.tail(n).query("decision == 1")['decision_update_rate'])

plt.scatter(x1, y1, marker='o', s = 30, alpha = 0.1, color="blue" ,label = "0")
plt.scatter(x2, y2, marker='o', s = 30, alpha = 0.1, color="red" ,label = "1")


plt.xlabel('decision_th')
plt.ylabel('decision_update_rate')
plt.legend(title = "decision", bbox_to_anchor=(1, 1), ncol=1)

plt.show()

# %%
plt.figure(figsize=(5,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 
    

x1 = list(agents_data.tail(n).query("decision == 0")['decision_th'])
y1 = list(agents_data.tail(n).query("decision == 0")['opinion'])

x2 = list(agents_data.tail(n).query("decision == 1")['decision_th'])
y2 = list(agents_data.tail(n).query("decision == 1")['opinion'])


plt.scatter(x1, y1, marker='o', s = 30, alpha = 0.1, color="blue" ,label = "0")
plt.scatter(x2, y2, marker='o', s = 30, alpha = 0.1, color="red" ,label = "1")


plt.xlabel('decision_th')
plt.ylabel('opinion')
plt.legend(title = "decision", bbox_to_anchor=(1, 1), ncol=1)

plt.show()

# %%
plt.figure(figsize=(5,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

x1 = []
x2 = []

for i in range(n):
    if list(agents_data.query(f"AgentID == {i}").tail(1)['decision'])[0] == 0:
        x1.append(model.agents_initial_opinions[i])
    else:
        x2.append(model.agents_initial_opinions[i])

y1 = list(agents_data.tail(n).query("decision == 0")['opinion'])
y2 = list(agents_data.tail(n).query("decision == 1")['opinion'])


plt.scatter(x1, y1, marker='o', s = 30, alpha = 0.1, color="blue" ,label = "0")
plt.scatter(x2, y2, marker='o', s = 30, alpha = 0.1, color="red" ,label = "1")


plt.xlabel('inital opinion')
plt.ylabel('final opinion')
plt.legend(title = "decision", bbox_to_anchor=(1, 1), ncol=1)

plt.show()

# %%
model.reinitialize_agents()
model.set_alpha(1)

for _ in range(num_steps):
    model.step()
    
model_data = model.datacollector.get_model_vars_dataframe()
agents_data = model.datacollector.get_agent_vars_dataframe()

# %%
agents_data['decision_update_count'] = (agents_data['move_counter'] + agents_data['stop_move_counter']) 
agents_data['decision_update_rate'] = agents_data['decision_update_count'] / num_steps

# %%
plt.figure(figsize=(5,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

x1 = list(agents_data.tail(n).query("decision == 0")['decision_th'])
y1 = list(agents_data.tail(n).query("decision == 0")['decision_update_rate'])

x2 = list(agents_data.tail(n).query("decision == 1")['decision_th'])
y2 = list(agents_data.tail(n).query("decision == 1")['decision_update_rate'])

plt.scatter(x1, y1, marker='o', s = 30, alpha = 0.1, color="blue" ,label = "0")
plt.scatter(x2, y2, marker='o', s = 30, alpha = 0.1, color="red" ,label = "1")


plt.xlabel('decision_th')
plt.ylabel('decision_update_rate')
plt.legend(title = "decision", bbox_to_anchor=(1, 1), ncol=1)

plt.show()

# %%
plt.figure(figsize=(5,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 
    

x1 = list(agents_data.tail(n).query("decision == 0")['decision_th'])
y1 = list(agents_data.tail(n).query("decision == 0")['opinion'])

x2 = list(agents_data.tail(n).query("decision == 1")['decision_th'])
y2 = list(agents_data.tail(n).query("decision == 1")['opinion'])


plt.scatter(x1, y1, marker='o', s = 30, alpha = 0.1, color="blue" ,label = "0")
plt.scatter(x2, y2, marker='o', s = 30, alpha = 0.1, color="red" ,label = "1")


plt.xlabel('decision_th')
plt.ylabel('opinion')
plt.legend(title = "decision", bbox_to_anchor=(1, 1), ncol=1)

plt.show()

# %%
plt.figure(figsize=(5,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

x1 = []
x2 = []

for i in range(n):
    if list(agents_data.query(f"AgentID == {i}").tail(1)['decision'])[0] == 0:
        x1.append(model.agents_initial_opinions[i])
    else:
        x2.append(model.agents_initial_opinions[i])

y1 = list(agents_data.tail(n).query("decision == 0")['opinion'])
y2 = list(agents_data.tail(n).query("decision == 1")['opinion'])


plt.scatter(x1, y1, marker='o', s = 30, alpha = 0.1, color="blue" ,label = "0")
plt.scatter(x2, y2, marker='o', s = 30, alpha = 0.1, color="red" ,label = "1")


plt.xlabel('inital opinion')
plt.ylabel('final opinion')
plt.legend(title = "decision", bbox_to_anchor=(1, 1), ncol=1)

plt.show()

# %% [markdown]
# ## Experiment 2: The impact of the agents’ attributes
#
# ### 1. Risk sensitivity  = 2 (all alarmist agents)

# %%
num_steps = 100
n = 500
h = 5 
w = 5

# %%
model = myModel(N = n, w = w , h = h , R = 2)

# %%
### alpha = 1

model.reinitialize_agents()
model.set_alpha(1)

for _ in range(num_steps):
    model.step()
    
model_data = model.datacollector.get_model_vars_dataframe()
agents_data = model.datacollector.get_agent_vars_dataframe()

alpha_1_decisions = list(model_data['mobility_rate'])
alpha_1_perception = list(model_data['combined_info_avg'])
alpha_1_op = list(model_data['op_avg']) 

alpha_1_start_move = list(model_data['start_moving_rate'])
alpha_1_stop_move = list(model_data['stop_moving_rate']) 
alpha_1_all_update = list(model_data['updated_decision_rate'])

# %%
agents_data['decision_update_count'] = (agents_data['move_counter'] + agents_data['stop_move_counter']) 
agents_data['decision_update_rate'] = agents_data['decision_update_count'] / num_steps

plt.figure(figsize=(5,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 
    

x1 = list(agents_data.tail(n).query("decision == 0")['decision_th'])
y1 = list(agents_data.tail(n).query("decision == 0")['opinion'])

x2 = list(agents_data.tail(n).query("decision == 1")['decision_th'])
y2 = list(agents_data.tail(n).query("decision == 1")['opinion'])


plt.scatter(x1, y1, marker='o', s = 30, alpha = 0.1, color="blue" ,label = "0")
plt.scatter(x2, y2, marker='o', s = 30, alpha = 0.1, color="red" ,label = "1")


plt.xlim(0,1)
plt.ylim(0,1.1)
plt.xlabel('decision_th')
plt.ylabel('risk perception')
plt.legend(title = "decision", bbox_to_anchor=(1, 1), ncol=1)

plt.show()

# %%
### alpha = 0.8

model.reinitialize_agents()
model.set_alpha(0.8)

for _ in range(num_steps):
    model.step()
    
model_data = model.datacollector.get_model_vars_dataframe()
agents_data = model.datacollector.get_agent_vars_dataframe()

alpha_08_decisions = list(model_data['mobility_rate'])
alpha_08_perception = list(model_data['combined_info_avg'])
alpha_08_op = list(model_data['op_avg']) 

alpha_08_start_move = list(model_data['start_moving_rate'])
alpha_08_stop_move = list(model_data['stop_moving_rate']) 
alpha_08_all_update = list(model_data['updated_decision_rate'])

# %%
agents_data['decision_update_count'] = (agents_data['move_counter'] + agents_data['stop_move_counter']) 
agents_data['decision_update_rate'] = agents_data['decision_update_count'] / num_steps

plt.figure(figsize=(5,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 
    

x1 = list(agents_data.tail(n).query("decision == 0")['decision_th'])
y1 = list(agents_data.tail(n).query("decision == 0")['combined_info'])

x2 = list(agents_data.tail(n).query("decision == 1")['decision_th'])
y2 = list(agents_data.tail(n).query("decision == 1")['combined_info'])


plt.scatter(x1, y1, marker='o', s = 30, alpha = 0.1, color="blue" ,label = "0")
plt.scatter(x2, y2, marker='o', s = 30, alpha = 0.1, color="red" ,label = "1")


plt.xlabel('decision_th')
plt.ylabel('risk perception')
plt.legend(title = "decision", bbox_to_anchor=(1, 1), ncol=1)

plt.show()

# %%
### alpha = 0.5

model.reinitialize_agents()
model.set_alpha(0.5)

for _ in range(num_steps):
    model.step()
    
model_data = model.datacollector.get_model_vars_dataframe()
agents_data = model.datacollector.get_agent_vars_dataframe()

alpha_05_decisions = list(model_data['mobility_rate'])
alpha_05_perception = list(model_data['combined_info_avg'])
alpha_05_op = list(model_data['op_avg']) 

alpha_05_start_move = list(model_data['start_moving_rate'])
alpha_05_stop_move = list(model_data['stop_moving_rate']) 
alpha_05_all_update = list(model_data['updated_decision_rate'])

# %%
agents_data['decision_update_count'] = (agents_data['move_counter'] + agents_data['stop_move_counter']) 
agents_data['decision_update_rate'] = agents_data['decision_update_count'] / num_steps

plt.figure(figsize=(5,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 
    

x1 = list(agents_data.tail(n).query("decision == 0")['decision_th'])
y1 = list(agents_data.tail(n).query("decision == 0")['combined_info'])

x2 = list(agents_data.tail(n).query("decision == 1")['decision_th'])
y2 = list(agents_data.tail(n).query("decision == 1")['combined_info'])


plt.scatter(x1, y1, marker='o', s = 30, alpha = 0.1, color="blue" ,label = "0")
plt.scatter(x2, y2, marker='o', s = 30, alpha = 0.1, color="red" ,label = "1")


plt.xlabel('decision_th')
plt.ylabel('risk perception')
plt.legend(title = "decision", bbox_to_anchor=(1, 1), ncol=1)

plt.show()

# %%
### alpha = 0.2

model.reinitialize_agents()
model.set_alpha(0.2)

for _ in range(num_steps):
    model.step()
    
model_data = model.datacollector.get_model_vars_dataframe()
agents_data = model.datacollector.get_agent_vars_dataframe()

alpha_02_decisions = list(model_data['mobility_rate'])
alpha_02_perception = list(model_data['combined_info_avg'])
alpha_02_op = list(model_data['op_avg']) 

alpha_02_start_move = list(model_data['start_moving_rate'])
alpha_02_stop_move = list(model_data['stop_moving_rate']) 
alpha_02_all_update = list(model_data['updated_decision_rate'])

# %%
agents_data['decision_update_count'] = (agents_data['move_counter'] + agents_data['stop_move_counter']) 
agents_data['decision_update_rate'] = agents_data['decision_update_count'] / num_steps

plt.figure(figsize=(5,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 
    

x1 = list(agents_data.tail(n).query("decision == 0")['decision_th'])
y1 = list(agents_data.tail(n).query("decision == 0")['combined_info'])

x2 = list(agents_data.tail(n).query("decision == 1")['decision_th'])
y2 = list(agents_data.tail(n).query("decision == 1")['combined_info'])


plt.scatter(x1, y1, marker='o', s = 30, alpha = 0.1, color="blue" ,label = "0")
plt.scatter(x2, y2, marker='o', s = 30, alpha = 0.1, color="red" ,label = "1")


plt.xlabel('decision_th')
plt.ylabel('risk perception')
plt.legend(title = "decision", bbox_to_anchor=(1, 1), ncol=1)

plt.show()

# %%
### alpha = 0

model.reinitialize_agents()
model.set_alpha(0)

for _ in range(num_steps):
    model.step()
    
model_data = model.datacollector.get_model_vars_dataframe()
agents_data = model.datacollector.get_agent_vars_dataframe()

alpha_0_decisions = list(model_data['mobility_rate'])
alpha_0_perception = list(model_data['combined_info_avg'])
alpha_0_op = list(model_data['op_avg']) 

alpha_0_start_move = list(model_data['start_moving_rate'])
alpha_0_stop_move = list(model_data['stop_moving_rate']) 
alpha_0_all_update = list(model_data['updated_decision_rate'])

# %%
agents_data['decision_update_count'] = (agents_data['move_counter'] + agents_data['stop_move_counter']) 
agents_data['decision_update_rate'] = agents_data['decision_update_count'] / num_steps

plt.figure(figsize=(5,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 
    

x1 = list(agents_data.tail(n).query("decision == 0")['decision_th'])
y1 = list(agents_data.tail(n).query("decision == 0")['combined_info'])

x2 = list(agents_data.tail(n).query("decision == 1")['decision_th'])
y2 = list(agents_data.tail(n).query("decision == 1")['combined_info'])


plt.scatter(x1, y1, marker='o', s = 30, alpha = 0.1, color="blue" ,label = "0")
plt.scatter(x2, y2, marker='o', s = 30, alpha = 0.1, color="red" ,label = "1")


plt.xlabel('decision_th')
plt.ylabel('risk perception')
plt.legend(title = "decision", bbox_to_anchor=(1, 1), ncol=1)

plt.show()

# %% [markdown]
# ### results

# %%
plt.figure(figsize=(5,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

x_values = list(range(num_steps))
 
sns.lineplot(x = x_values , y = alpha_1_decisions , label = "1")
sns.lineplot(x = x_values , y = alpha_08_decisions , label = "0.8") 
sns.lineplot(x = x_values , y = alpha_05_decisions , label = "0.5") 
sns.lineplot(x = x_values , y = alpha_02_decisions , label = "0.2") 
sns.lineplot(x = x_values , y = alpha_0_decisions , label = "0") 


plt.ylim(-0.02,1)
plt.xlabel("Time step")
plt.ylabel("Mobility rate")
plt.legend(title = "alpha", bbox_to_anchor=(1, 1), ncol=1)

plt.show()

# %%
plt.figure(figsize=(5,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

x_values = list(range(num_steps))
 
sns.lineplot(x = x_values , y = alpha_1_perception , label = "1") 
sns.lineplot(x = x_values , y = alpha_08_perception , label = "0.8") 
sns.lineplot(x = x_values , y = alpha_05_perception , label = "0.5") 
sns.lineplot(x = x_values , y = alpha_02_perception , label = "0.2") 
sns.lineplot(x = x_values , y = alpha_0_perception , label = "0") 

plt.ylim(0,1.02)
plt.xlabel("Time step")
plt.ylabel("Collective risk perception")
plt.legend(title = "alpha", bbox_to_anchor=(1, 1), ncol=1)

plt.show()

# %% [markdown]
# might not be that usefull

# %%
plt.figure(figsize=(5,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

x_values = list(range(num_steps))

sns.lineplot(x = x_values , y = alpha_1_all_update , label = "1")
sns.lineplot(x = x_values , y = alpha_08_all_update , label = "0.8")
sns.lineplot(x = x_values , y = alpha_05_all_update , label = "0.5")
sns.lineplot(x = x_values , y = alpha_02_all_update , label = "0.2")
sns.lineplot(x = x_values , y = alpha_0_all_update , label = "0")

# plt.ylim(0,1)
plt.xlabel("Time step")
plt.ylabel("")
plt.legend(title = "alpha", bbox_to_anchor=(1, 1), ncol=1)

plt.show()

# %% [markdown]
# ### 2. Risk sensitivity  = 1 (all nuteral agents)

# %%
num_steps = 100
n = 500
h = 5 
w = 5

# %%
model = myModel(N = n, w = w , h = h , R = 1)

# %%
### alpha = 1

model.reinitialize_agents()
model.set_alpha(1)

for _ in range(num_steps):
    model.step()
    
model_data = model.datacollector.get_model_vars_dataframe()
agents_data = model.datacollector.get_agent_vars_dataframe()

alpha_1_decisions = list(model_data['mobility_rate'])
alpha_1_perception = list(model_data['combined_info_avg'])
alpha_1_op = list(model_data['op_avg']) 

alpha_1_start_move = list(model_data['start_moving_rate'])
alpha_1_stop_move = list(model_data['stop_moving_rate']) 
alpha_1_all_update = list(model_data['updated_decision_rate'])

# %%
agents_data['decision_update_count'] = (agents_data['move_counter'] + agents_data['stop_move_counter']) 
agents_data['decision_update_rate'] = agents_data['decision_update_count'] / num_steps

plt.figure(figsize=(5,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 
    

x1 = list(agents_data.tail(n).query("decision == 0")['decision_th'])
y1 = list(agents_data.tail(n).query("decision == 0")['opinion'])

x2 = list(agents_data.tail(n).query("decision == 1")['decision_th'])
y2 = list(agents_data.tail(n).query("decision == 1")['opinion'])


plt.scatter(x1, y1, marker='o', s = 30, alpha = 0.1, color="blue" ,label = "0")
plt.scatter(x2, y2, marker='o', s = 30, alpha = 0.1, color="red" ,label = "1")


plt.xlim(0,1)
plt.ylim(0,1.1)
plt.xlabel('decision_th')
plt.ylabel('risk perception')
plt.legend(title = "decision", bbox_to_anchor=(1, 1), ncol=1)

plt.show()

# %%
### alpha = 0.8

model.reinitialize_agents()
model.set_alpha(0.8)

for _ in range(num_steps):
    model.step()
    
model_data = model.datacollector.get_model_vars_dataframe()
agents_data = model.datacollector.get_agent_vars_dataframe()

alpha_08_decisions = list(model_data['mobility_rate'])
alpha_08_perception = list(model_data['combined_info_avg'])
alpha_08_op = list(model_data['op_avg']) 

alpha_08_start_move = list(model_data['start_moving_rate'])
alpha_08_stop_move = list(model_data['stop_moving_rate']) 
alpha_08_all_update = list(model_data['updated_decision_rate'])

# %%
agents_data['decision_update_count'] = (agents_data['move_counter'] + agents_data['stop_move_counter']) 
agents_data['decision_update_rate'] = agents_data['decision_update_count'] / num_steps

plt.figure(figsize=(5,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 
    

x1 = list(agents_data.tail(n).query("decision == 0")['decision_th'])
y1 = list(agents_data.tail(n).query("decision == 0")['combined_info'])

x2 = list(agents_data.tail(n).query("decision == 1")['decision_th'])
y2 = list(agents_data.tail(n).query("decision == 1")['combined_info'])


plt.scatter(x1, y1, marker='o', s = 30, alpha = 0.1, color="blue" ,label = "0")
plt.scatter(x2, y2, marker='o', s = 30, alpha = 0.1, color="red" ,label = "1")


plt.xlabel('decision_th')
plt.ylabel('risk perception')
plt.legend(title = "decision", bbox_to_anchor=(1, 1), ncol=1)

plt.show()

# %%
### alpha = 0.5

model.reinitialize_agents()
model.set_alpha(0.5)

for _ in range(num_steps):
    model.step()
    
model_data = model.datacollector.get_model_vars_dataframe()
agents_data = model.datacollector.get_agent_vars_dataframe()

alpha_05_decisions = list(model_data['mobility_rate'])
alpha_05_perception = list(model_data['combined_info_avg'])
alpha_05_op = list(model_data['op_avg']) 

alpha_05_start_move = list(model_data['start_moving_rate'])
alpha_05_stop_move = list(model_data['stop_moving_rate']) 
alpha_05_all_update = list(model_data['updated_decision_rate'])

# %%
agents_data['decision_update_count'] = (agents_data['move_counter'] + agents_data['stop_move_counter']) 
agents_data['decision_update_rate'] = agents_data['decision_update_count'] / num_steps

plt.figure(figsize=(5,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 
    

x1 = list(agents_data.tail(n).query("decision == 0")['decision_th'])
y1 = list(agents_data.tail(n).query("decision == 0")['combined_info'])

x2 = list(agents_data.tail(n).query("decision == 1")['decision_th'])
y2 = list(agents_data.tail(n).query("decision == 1")['combined_info'])


plt.scatter(x1, y1, marker='o', s = 30, alpha = 0.1, color="blue" ,label = "0")
plt.scatter(x2, y2, marker='o', s = 30, alpha = 0.1, color="red" ,label = "1")


plt.xlabel('decision_th')
plt.ylabel('risk perception')
plt.legend(title = "decision", bbox_to_anchor=(1, 1), ncol=1)

plt.show()

# %%
### alpha = 0.2

model.reinitialize_agents()
model.set_alpha(0.2)

for _ in range(num_steps):
    model.step()
    
model_data = model.datacollector.get_model_vars_dataframe()
agents_data = model.datacollector.get_agent_vars_dataframe()

alpha_02_decisions = list(model_data['mobility_rate'])
alpha_02_perception = list(model_data['combined_info_avg'])
alpha_02_op = list(model_data['op_avg']) 

alpha_02_start_move = list(model_data['start_moving_rate'])
alpha_02_stop_move = list(model_data['stop_moving_rate']) 
alpha_02_all_update = list(model_data['updated_decision_rate'])

# %%
agents_data['decision_update_count'] = (agents_data['move_counter'] + agents_data['stop_move_counter']) 
agents_data['decision_update_rate'] = agents_data['decision_update_count'] / num_steps

plt.figure(figsize=(5,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 
    

x1 = list(agents_data.tail(n).query("decision == 0")['decision_th'])
y1 = list(agents_data.tail(n).query("decision == 0")['combined_info'])

x2 = list(agents_data.tail(n).query("decision == 1")['decision_th'])
y2 = list(agents_data.tail(n).query("decision == 1")['combined_info'])


plt.scatter(x1, y1, marker='o', s = 30, alpha = 0.1, color="blue" ,label = "0")
plt.scatter(x2, y2, marker='o', s = 30, alpha = 0.1, color="red" ,label = "1")


plt.xlabel('decision_th')
plt.ylabel('risk perception')
plt.legend(title = "decision", bbox_to_anchor=(1, 1), ncol=1)

plt.show()

# %%
### alpha = 0

model.reinitialize_agents()
model.set_alpha(0)

for _ in range(num_steps):
    model.step()
    
model_data = model.datacollector.get_model_vars_dataframe()
agents_data = model.datacollector.get_agent_vars_dataframe()

alpha_0_decisions = list(model_data['mobility_rate'])
alpha_0_perception = list(model_data['combined_info_avg'])
alpha_0_op = list(model_data['op_avg']) 

alpha_0_start_move = list(model_data['start_moving_rate'])
alpha_0_stop_move = list(model_data['stop_moving_rate']) 
alpha_0_all_update = list(model_data['updated_decision_rate'])

# %%
agents_data['decision_update_count'] = (agents_data['move_counter'] + agents_data['stop_move_counter']) 
agents_data['decision_update_rate'] = agents_data['decision_update_count'] / num_steps

plt.figure(figsize=(5,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 
    

x1 = list(agents_data.tail(n).query("decision == 0")['decision_th'])
y1 = list(agents_data.tail(n).query("decision == 0")['combined_info'])

x2 = list(agents_data.tail(n).query("decision == 1")['decision_th'])
y2 = list(agents_data.tail(n).query("decision == 1")['combined_info'])


plt.scatter(x1, y1, marker='o', s = 30, alpha = 0.1, color="blue" ,label = "0")
plt.scatter(x2, y2, marker='o', s = 30, alpha = 0.1, color="red" ,label = "1")


plt.xlabel('decision_th')
plt.ylabel('risk perception')
plt.legend(title = "decision", bbox_to_anchor=(1, 1), ncol=1)

plt.show()

# %%
plt.figure(figsize=(5,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

x_values = list(range(num_steps))
 
sns.lineplot(x = x_values , y = alpha_1_decisions , label = "1")
sns.lineplot(x = x_values , y = alpha_08_decisions , label = "0.8") 
sns.lineplot(x = x_values , y = alpha_05_decisions , label = "0.5") 
sns.lineplot(x = x_values , y = alpha_02_decisions , label = "0.2") 
sns.lineplot(x = x_values , y = alpha_0_decisions , label = "0") 


plt.ylim(-0.02,1)
plt.xlabel("Time step")
plt.ylabel("Mobility rate")
plt.legend(title = "alpha", bbox_to_anchor=(1, 1), ncol=1)

plt.show()

# %%
plt.figure(figsize=(5,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

x_values = list(range(num_steps))
 
sns.lineplot(x = x_values , y = alpha_1_perception , label = "1") 
sns.lineplot(x = x_values , y = alpha_08_perception , label = "0.8") 
sns.lineplot(x = x_values , y = alpha_05_perception , label = "0.5") 
sns.lineplot(x = x_values , y = alpha_02_perception , label = "0.2") 
sns.lineplot(x = x_values , y = alpha_0_perception , label = "0") 

plt.ylim(0,1.02)
plt.xlabel("Time step")
plt.ylabel("Collective risk perception")
plt.legend(title = "alpha", bbox_to_anchor=(1, 1), ncol=1)

plt.show()

# %% [markdown]
# might not be that usefull

# %%
plt.figure(figsize=(5,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

x_values = list(range(num_steps))

sns.lineplot(x = x_values , y = alpha_1_all_update , label = "1")
sns.lineplot(x = x_values , y = alpha_08_all_update , label = "0.8")
sns.lineplot(x = x_values , y = alpha_05_all_update , label = "0.5")
sns.lineplot(x = x_values , y = alpha_02_all_update , label = "0.2")
sns.lineplot(x = x_values , y = alpha_0_all_update , label = "0")

# plt.ylim(0,1)
plt.xlabel("Time step")
plt.ylabel("")
plt.legend(title = "alpha", bbox_to_anchor=(1, 1), ncol=1)

plt.show()

# %% [markdown]
# ### 2. Risk sensitivity  = 0 (all non-alarmist agents)

# %%
num_steps = 100
n = 500
h = 5 
w = 5

# %%
model = myModel(N = n, w = w , h = h , R = 0)

# %%
### alpha = 1

model.reinitialize_agents()
model.set_alpha(1)

for _ in range(num_steps):
    model.step()
    
model_data = model.datacollector.get_model_vars_dataframe()
agents_data = model.datacollector.get_agent_vars_dataframe()

alpha_1_decisions = list(model_data['mobility_rate'])
alpha_1_perception = list(model_data['combined_info_avg'])
alpha_1_op = list(model_data['op_avg']) 

alpha_1_start_move = list(model_data['start_moving_rate'])
alpha_1_stop_move = list(model_data['stop_moving_rate']) 
alpha_1_all_update = list(model_data['updated_decision_rate'])

# %%
agents_data['decision_update_count'] = (agents_data['move_counter'] + agents_data['stop_move_counter']) 
agents_data['decision_update_rate'] = agents_data['decision_update_count'] / num_steps

plt.figure(figsize=(5,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 
    

x1 = list(agents_data.tail(n).query("decision == 0")['decision_th'])
y1 = list(agents_data.tail(n).query("decision == 0")['opinion'])

x2 = list(agents_data.tail(n).query("decision == 1")['decision_th'])
y2 = list(agents_data.tail(n).query("decision == 1")['opinion'])


plt.scatter(x1, y1, marker='o', s = 30, alpha = 0.1, color="blue" ,label = "0")
plt.scatter(x2, y2, marker='o', s = 30, alpha = 0.1, color="red" ,label = "1")


plt.xlim(0,1)
plt.ylim(0,1.1)
plt.xlabel('decision_th')
plt.ylabel('risk perception')
plt.legend(title = "decision", bbox_to_anchor=(1, 1), ncol=1)

plt.show()

# %%
### alpha = 0.8

model.reinitialize_agents()
model.set_alpha(0.8)

for _ in range(num_steps):
    model.step()
    
model_data = model.datacollector.get_model_vars_dataframe()
agents_data = model.datacollector.get_agent_vars_dataframe()

alpha_08_decisions = list(model_data['mobility_rate'])
alpha_08_perception = list(model_data['combined_info_avg'])
alpha_08_op = list(model_data['op_avg']) 

alpha_08_start_move = list(model_data['start_moving_rate'])
alpha_08_stop_move = list(model_data['stop_moving_rate']) 
alpha_08_all_update = list(model_data['updated_decision_rate'])

# %%
agents_data['decision_update_count'] = (agents_data['move_counter'] + agents_data['stop_move_counter']) 
agents_data['decision_update_rate'] = agents_data['decision_update_count'] / num_steps

plt.figure(figsize=(5,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 
    

x1 = list(agents_data.tail(n).query("decision == 0")['decision_th'])
y1 = list(agents_data.tail(n).query("decision == 0")['combined_info'])

x2 = list(agents_data.tail(n).query("decision == 1")['decision_th'])
y2 = list(agents_data.tail(n).query("decision == 1")['combined_info'])


plt.scatter(x1, y1, marker='o', s = 30, alpha = 0.1, color="blue" ,label = "0")
plt.scatter(x2, y2, marker='o', s = 30, alpha = 0.1, color="red" ,label = "1")


plt.xlabel('decision_th')
plt.ylabel('risk perception')
plt.legend(title = "decision", bbox_to_anchor=(1, 1), ncol=1)

plt.show()

# %%
### alpha = 0.5

model.reinitialize_agents()
model.set_alpha(0.5)

for _ in range(num_steps):
    model.step()
    
model_data = model.datacollector.get_model_vars_dataframe()
agents_data = model.datacollector.get_agent_vars_dataframe()

alpha_05_decisions = list(model_data['mobility_rate'])
alpha_05_perception = list(model_data['combined_info_avg'])
alpha_05_op = list(model_data['op_avg']) 

alpha_05_start_move = list(model_data['start_moving_rate'])
alpha_05_stop_move = list(model_data['stop_moving_rate']) 
alpha_05_all_update = list(model_data['updated_decision_rate'])

# %%
agents_data['decision_update_count'] = (agents_data['move_counter'] + agents_data['stop_move_counter']) 
agents_data['decision_update_rate'] = agents_data['decision_update_count'] / num_steps

plt.figure(figsize=(5,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 
    

x1 = list(agents_data.tail(n).query("decision == 0")['decision_th'])
y1 = list(agents_data.tail(n).query("decision == 0")['combined_info'])

x2 = list(agents_data.tail(n).query("decision == 1")['decision_th'])
y2 = list(agents_data.tail(n).query("decision == 1")['combined_info'])


plt.scatter(x1, y1, marker='o', s = 30, alpha = 0.1, color="blue" ,label = "0")
plt.scatter(x2, y2, marker='o', s = 30, alpha = 0.1, color="red" ,label = "1")


plt.xlabel('decision_th')
plt.ylabel('risk perception')
plt.legend(title = "decision", bbox_to_anchor=(1, 1), ncol=1)

plt.show()

# %%
### alpha = 0.2

model.reinitialize_agents()
model.set_alpha(0.2)

for _ in range(num_steps):
    model.step()
    
model_data = model.datacollector.get_model_vars_dataframe()
agents_data = model.datacollector.get_agent_vars_dataframe()

alpha_02_decisions = list(model_data['mobility_rate'])
alpha_02_perception = list(model_data['combined_info_avg'])
alpha_02_op = list(model_data['op_avg']) 

alpha_02_start_move = list(model_data['start_moving_rate'])
alpha_02_stop_move = list(model_data['stop_moving_rate']) 
alpha_02_all_update = list(model_data['updated_decision_rate'])

# %%
agents_data['decision_update_count'] = (agents_data['move_counter'] + agents_data['stop_move_counter']) 
agents_data['decision_update_rate'] = agents_data['decision_update_count'] / num_steps

plt.figure(figsize=(5,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 
    

x1 = list(agents_data.tail(n).query("decision == 0")['decision_th'])
y1 = list(agents_data.tail(n).query("decision == 0")['combined_info'])

x2 = list(agents_data.tail(n).query("decision == 1")['decision_th'])
y2 = list(agents_data.tail(n).query("decision == 1")['combined_info'])


plt.scatter(x1, y1, marker='o', s = 30, alpha = 0.1, color="blue" ,label = "0")
plt.scatter(x2, y2, marker='o', s = 30, alpha = 0.1, color="red" ,label = "1")


plt.xlabel('decision_th')
plt.ylabel('risk perception')
plt.legend(title = "decision", bbox_to_anchor=(1, 1), ncol=1)

plt.show()

# %%
### alpha = 0

model.reinitialize_agents()
model.set_alpha(0)

for _ in range(num_steps):
    model.step()
    
model_data = model.datacollector.get_model_vars_dataframe()
agents_data = model.datacollector.get_agent_vars_dataframe()

alpha_0_decisions = list(model_data['mobility_rate'])
alpha_0_perception = list(model_data['combined_info_avg'])
alpha_0_op = list(model_data['op_avg']) 

alpha_0_start_move = list(model_data['start_moving_rate'])
alpha_0_stop_move = list(model_data['stop_moving_rate']) 
alpha_0_all_update = list(model_data['updated_decision_rate'])

# %%
agents_data['decision_update_count'] = (agents_data['move_counter'] + agents_data['stop_move_counter']) 
agents_data['decision_update_rate'] = agents_data['decision_update_count'] / num_steps

plt.figure(figsize=(5,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 
    

x1 = list(agents_data.tail(n).query("decision == 0")['decision_th'])
y1 = list(agents_data.tail(n).query("decision == 0")['combined_info'])

x2 = list(agents_data.tail(n).query("decision == 1")['decision_th'])
y2 = list(agents_data.tail(n).query("decision == 1")['combined_info'])


plt.scatter(x1, y1, marker='o', s = 30, alpha = 0.1, color="blue" ,label = "0")
plt.scatter(x2, y2, marker='o', s = 30, alpha = 0.1, color="red" ,label = "1")


plt.xlabel('decision_th')
plt.ylabel('risk perception')
plt.legend(title = "decision", bbox_to_anchor=(1, 1), ncol=1)

plt.show()

# %%
plt.figure(figsize=(5,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

x_values = list(range(num_steps))
 
sns.lineplot(x = x_values , y = alpha_1_decisions , label = "1")
sns.lineplot(x = x_values , y = alpha_08_decisions , label = "0.8") 
sns.lineplot(x = x_values , y = alpha_05_decisions , label = "0.5") 
sns.lineplot(x = x_values , y = alpha_02_decisions , label = "0.2") 
sns.lineplot(x = x_values , y = alpha_0_decisions , label = "0") 


plt.ylim(-0.02,1)
plt.xlabel("Time step")
plt.ylabel("Mobility rate")
plt.legend(title = "alpha", bbox_to_anchor=(1, 1), ncol=1)

plt.show()

# %%
plt.figure(figsize=(5,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

x_values = list(range(num_steps))
 
sns.lineplot(x = x_values , y = alpha_1_perception , label = "1") 
sns.lineplot(x = x_values , y = alpha_08_perception , label = "0.8") 
sns.lineplot(x = x_values , y = alpha_05_perception , label = "0.5") 
sns.lineplot(x = x_values , y = alpha_02_perception , label = "0.2") 
sns.lineplot(x = x_values , y = alpha_0_perception , label = "0") 

plt.ylim(0,1.02)
plt.xlabel("Time step")
plt.ylabel("Collective risk perception")
plt.legend(title = "alpha", bbox_to_anchor=(1, 1), ncol=1)

plt.show()

# %% [markdown]
# might not be that usefull

# %%
plt.figure(figsize=(5,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

x_values = list(range(num_steps))

sns.lineplot(x = x_values , y = alpha_1_all_update , label = "1")
sns.lineplot(x = x_values , y = alpha_08_all_update , label = "0.8")
sns.lineplot(x = x_values , y = alpha_05_all_update , label = "0.5")
sns.lineplot(x = x_values , y = alpha_02_all_update , label = "0.2")
sns.lineplot(x = x_values , y = alpha_0_all_update , label = "0")

# plt.ylim(0,1)
plt.xlabel("Time step")
plt.ylabel("")
plt.legend(title = "alpha", bbox_to_anchor=(1, 1), ncol=1)

plt.show()

# %% [markdown]
# ### Peer Trusr

# %%
model = myModel(N = 1000, w = 1 , h = 1, PT = -1, B = -1, R = -1, dt = -1)

# %%
model_data = model.datacollector.get_model_vars_dataframe()
agents_data = model.datacollector.get_agent_vars_dataframe()

# %%
plt.figure(figsize=(3,  2))
sns.histplot(agents_data.query('Step == 0')['opinion'], kde=True)
plt.title('op')
plt.show()

# %%
plt.figure(figsize=(3,  2))
sns.histplot(agents_data.query('Step == 0')['peer_trust'], kde=True)
plt.title('PT')
plt.show()

# %%
plt.figure(figsize=(3,  2))
sns.histplot(agents_data.query('Step == 0')['risk_sensitivity'], kde=True)
plt.title('R')
plt.show()

# %%
plt.figure(figsize=(3,  2))
sns.histplot(agents_data.query('Step == 0')['tendency_to_share'], kde=True)
plt.title('B')
plt.show()

# %%
plt.figure(figsize=(3,  2))
sns.histplot(agents_data.query('Step == 0')['decision_th'], kde=True)
plt.title('dt')
plt.show()

# %%
model = myModel(N = 500, w = 5 , h = 5, PT = -1)

for _ in range(100):
    model.step()
    
model_data = model.datacollector.get_model_vars_dataframe()
agents_data = model.datacollector.get_agent_vars_dataframe()

PT_all_decisions = list(model_data['mobility_rate'])
PT_all_perception = list(model_data['combined_info_avg'])
PT_all_op = list(model_data['op_avg']) 

PT_all_start_move = list(model_data['start_moving_rate'])
PT_all_stop_move = list(model_data['stop_moving_rate']) 
PT_all_all_update = list(model_data['updated_decision_rate'])

# %%
model = myModel(N = 500, w = 5 , h = 5, PT = "high")

for _ in range(100):
    model.step()
    
model_data = model.datacollector.get_model_vars_dataframe()

PT_high_decisions = list(model_data['mobility_rate'])
PT_high_perception = list(model_data['combined_info_avg'])
PT_high_op = list(model_data['op_avg']) 

PT_high_start_move = list(model_data['start_moving_rate'])
PT_high_stop_move = list(model_data['stop_moving_rate']) 
PT_high_all_update = list(model_data['updated_decision_rate'])

########################

agents_data = model.datacollector.get_agent_vars_dataframe()

agents_data['decision_update_rate'] = (agents_data['move_counter'] + agents_data['stop_move_counter']) / 100

PT_high_dt_0 = list(agents_data.tail(500).query("decision == 0")['decision_th'])
PT_high_dt_1 = list(agents_data.tail(500).query("decision == 1")['decision_th'])

PT_high_init_op_0 = list(agents_data.head(500).query("decision == 0")['old_opinion'])
PT_high_init_op_1 = list(agents_data.head(500).query("decision == 1")['old_opinion'])

PT_high_final_op_0 = list(agents_data.tail(500).query("decision == 0")['old_opinion'])
PT_high_final_op_1 = list(agents_data.tail(500).query("decision == 1")['old_opinion'])

PT_high_combined_info_0 = list(agents_data.tail(500).query("decision == 0")['combined_info'])
PT_high_combined_info_1 = list(agents_data.tail(500).query("decision == 1")['combined_info'])

PT_high_mobility_0 = list(agents_data.tail(500).query("decision == 0")['observed_mobility'])
PT_high_mobility_1 = list(agents_data.tail(500).query("decision == 1")['observed_mobility'])

PT_high_d_update_0 = list(agents_data.tail(500).query("decision == 0")['decision_update_rate'])
PT_high_d_update_1 = list(agents_data.tail(500).query("decision == 1")['decision_update_rate'])

# %%
model = myModel(N = 500, w = 5 , h = 5, PT = "mid")

for _ in range(100):
    model.step()
    
model_data = model.datacollector.get_model_vars_dataframe()

PT_mid_decisions = list(model_data['mobility_rate'])
PT_mid_perception = list(model_data['combined_info_avg'])
PT_mid_op = list(model_data['op_avg']) 

PT_mid_start_move = list(model_data['start_moving_rate'])
PT_mid_stop_move = list(model_data['stop_moving_rate']) 
PT_mid_all_update = list(model_data['updated_decision_rate']) 

########################

agents_data = model.datacollector.get_agent_vars_dataframe()

agents_data['decision_update_rate'] = (agents_data['move_counter'] + agents_data['stop_move_counter']) / 100

PT_mid_dt_0 = list(agents_data.tail(500).query("decision == 0")['decision_th'])
PT_mid_dt_1 = list(agents_data.tail(500).query("decision == 1")['decision_th'])

PT_mid_init_op_0 = list(agents_data.head(500).query("decision == 0")['old_opinion'])
PT_mid_init_op_1 = list(agents_data.head(500).query("decision == 1")['old_opinion'])

PT_mid_final_op_0 = list(agents_data.tail(500).query("decision == 0")['old_opinion'])
PT_mid_final_op_1 = list(agents_data.tail(500).query("decision == 1")['old_opinion'])

PT_mid_combined_info_0 = list(agents_data.tail(500).query("decision == 0")['combined_info'])
PT_mid_combined_info_1 = list(agents_data.tail(500).query("decision == 1")['combined_info'])

PT_mid_mobility_0 = list(agents_data.tail(500).query("decision == 0")['observed_mobility'])
PT_mid_mobility_1 = list(agents_data.tail(500).query("decision == 1")['observed_mobility'])

PT_mid_d_update_0 = list(agents_data.tail(500).query("decision == 0")['decision_update_rate'])
PT_mid_d_update_1 = list(agents_data.tail(500).query("decision == 1")['decision_update_rate'])

# %%
model = myModel(N = 500, w = 5 , h = 5, PT = "low")

for _ in range(100):
    model.step()
    
model_data = model.datacollector.get_model_vars_dataframe()

PT_low_decisions = list(model_data['mobility_rate'])
PT_low_perception = list(model_data['combined_info_avg'])
PT_low_op = list(model_data['op_avg']) 

PT_low_start_move = list(model_data['start_moving_rate'])
PT_low_stop_move = list(model_data['stop_moving_rate']) 
PT_low_all_update = list(model_data['updated_decision_rate']) 

########################

agents_data = model.datacollector.get_agent_vars_dataframe()

agents_data['decision_update_rate'] = (agents_data['move_counter'] + agents_data['stop_move_counter']) / 100

PT_low_dt_0 = list(agents_data.tail(500).query("decision == 0")['decision_th'])
PT_low_dt_1 = list(agents_data.tail(500).query("decision == 1")['decision_th'])

PT_low_init_op_0 = list(agents_data.head(500).query("decision == 0")['old_opinion'])
PT_low_init_op_1 = list(agents_data.head(500).query("decision == 1")['old_opinion'])

PT_low_final_op_0 = list(agents_data.tail(500).query("decision == 0")['old_opinion'])
PT_low_final_op_1 = list(agents_data.tail(500).query("decision == 1")['old_opinion'])

PT_low_combined_info_0 = list(agents_data.tail(500).query("decision == 0")['combined_info'])
PT_low_combined_info_1 = list(agents_data.tail(500).query("decision == 1")['combined_info'])

PT_low_mobility_0 = list(agents_data.tail(500).query("decision == 0")['observed_mobility'])
PT_low_mobility_1 = list(agents_data.tail(500).query("decision == 1")['observed_mobility'])

PT_low_d_update_0 = list(agents_data.tail(500).query("decision == 0")['decision_update_rate'])
PT_low_d_update_1 = list(agents_data.tail(500).query("decision == 1")['decision_update_rate'])

# %%
plt.figure(figsize=(5,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

x_values = list(range(101))
 
sns.lineplot(x = x_values , y = PT_low_decisions , label = "low")
sns.lineplot(x = x_values , y = PT_mid_decisions , label = "mid")
sns.lineplot(x = x_values , y = PT_high_decisions , label = "high")
sns.lineplot(x = x_values , y = PT_all_decisions , label = "all")

plt.xlabel("Time step")
plt.ylabel("Mobility rate")
plt.legend(title = "PT", bbox_to_anchor=(1, 1), ncol=1)

plt.ylim(0,1)

plt.show()

# %%
plt.figure(figsize=(5,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

x_values = list(range(101))
 
sns.lineplot(x = x_values , y = PT_low_op , label = "low")
sns.lineplot(x = x_values , y = PT_mid_op , label = "mid")
sns.lineplot(x = x_values , y = PT_high_op , label = "high")
sns.lineplot(x = x_values , y = PT_all_op , label = "all")

plt.xlabel("Time step")
plt.ylabel("Mobility rate")
plt.legend(title = "PT", bbox_to_anchor=(1, 1), ncol=1)

plt.ylim(0,1)

plt.show()

# %%
plt.figure(figsize=(5,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

x_values = list(range(100))
 
sns.lineplot(x = x_values , y = PT_low_stop_move[1:] , label = "low")
sns.lineplot(x = x_values , y = PT_mid_stop_move[1:] , label = "mid")
sns.lineplot(x = x_values , y = PT_high_stop_move[1:] , label = "high")
sns.lineplot(x = x_values , y = PT_all_stop_move[1:] , label = "all")

plt.xlabel("Time step")
plt.ylabel("Mobility rate")
plt.legend(title = "PT", bbox_to_anchor=(1, 1), ncol=1)

# plt.ylim(0,1)

plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(7.5, 2.75))

# Loop through each subplot
for ax in axs:
    # Remove spines on all sides
    for pos in ['right', 'top', 'bottom', 'left']: 
        ax.spines[pos].set_visible(False)
        
x_values = list(range(101))
 
axs[0].plot(x_values , PT_low_decisions , label = "low")
axs[0].plot(x_values , PT_mid_decisions , label = "mid")
axs[0].plot(x_values , PT_high_decisions , label = "high")
axs[0].plot(x_values , PT_all_decisions , label = "all")
axs[0].set_ylabel('Mobility rate')

axs[1].plot(x_values , PT_low_op , label = "low")
axs[1].plot(x_values , PT_mid_op , label = "mid")
axs[1].plot(x_values , PT_high_op , label = "high")
axs[1].plot(x_values , PT_all_op , label = "all")
axs[1].set_ylabel('Risk perception')

# Adjust layout
plt.tight_layout()


# Add common x-axis label
for ax in axs:
    ax.set_xlabel("Time step")
    ax.set_ylim(0,1)
    

plt.legend(title = "PT", bbox_to_anchor=(1.05, 0.8), ncol=1)

# Show plots
plt.show()

# %%
fig, axs = plt.subplots(2, 3, figsize=(10, 5))



axs[0,0].set_title('High PT')
axs[0,1].set_title('Mid PT')
axs[0,2].set_title('Low PT')

axs[0,0].set_ylabel('Observed Mobility' )

axs[0,0].scatter(PT_high_final_op_0, PT_high_mobility_0, marker='o', s = 20, alpha = 0.1, color="blue")
axs[0,1].scatter(PT_mid_final_op_0, PT_mid_mobility_0, marker='o', s = 20, alpha = 0.1, color="blue")
axs[0,2].scatter(PT_low_final_op_0, PT_low_mobility_0, marker='o', s = 20, alpha = 0.1, color="blue")

# axs[0,0].set_xlabel('opinion')
# axs[0,1].set_xlabel('opinion')
# axs[0,2].set_xlabel('opinion')

################################

axs[1,0].set_ylabel('Observed Mobility' )

axs[1,0].scatter(PT_high_final_op_1, PT_high_mobility_1, marker='o', s = 20, alpha = 0.1, color="red")
axs[1,1].scatter(PT_mid_final_op_1, PT_mid_mobility_1, marker='o', s = 20, alpha = 0.1, color="red")
axs[1,2].scatter(PT_low_final_op_1, PT_low_mobility_1, marker='o', s = 20, alpha = 0.1, color="red")

axs[1,0].set_xlabel('opinion')
axs[1,1].set_xlabel('opinion')
axs[1,2].set_xlabel('opinion')


for i in [0,1]:
    for j in [0,1,2]:
        for pos in ['right', 'top', 'bottom', 'left']: 
            axs[i][j].spines[pos].set_visible(False)

        axs[i][j].set_ylim(-0.02,1.02)
        axs[i][j].set_xticks([0, 0.5, 1])  
        axs[i][j].set_yticks([0, 0.5, 1])  
    

# Create custom legend handles
handles = [plt.Line2D([], [], marker='o', markersize=7, color='red', linestyle='None', alpha=0.3),
          plt.Line2D([], [], marker='o', markersize=7, color='blue', linestyle='None', alpha=0.3)]

axs[0,2].legend(handles, ["Move","Don't move"], ncol=1, bbox_to_anchor=(1, 1) ,fontsize = "small", title = "Decision")

# fig.text(0.38, -0.02, 'Risk perception')

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, 3, figsize=(10, 5))


axs[0,0].set_title('High PT')
axs[0,1].set_title('Mid PT')
axs[0,2].set_title('Low PT')

axs[0,0].set_ylabel('Risk-tolerance threshold' )

axs[0,0].scatter(PT_high_combined_info_0, PT_high_dt_0, marker='o', s = 20, alpha = 0.1, color="blue")
axs[0,0].scatter(PT_high_combined_info_1, PT_high_dt_1, marker='o', s = 20, alpha = 0.1, color="red")

axs[0,1].scatter(PT_mid_combined_info_0, PT_mid_dt_0, marker='o', s = 20, alpha = 0.1, color="blue")
axs[0,1].scatter(PT_mid_combined_info_1, PT_mid_dt_1, marker='o', s = 20, alpha = 0.1, color="red")

axs[0,2].scatter(PT_low_combined_info_0, PT_low_dt_0, marker='o', s = 20, alpha = 0.1, color="blue")
axs[0,2].scatter(PT_low_combined_info_1, PT_low_dt_1, marker='o', s = 20, alpha = 0.1, color="red")


# axs[0,0].set_xlabel('Combined risk perception')
# axs[0,1].set_xlabel('Combined risk perception')
# axs[0,2].set_xlabel('Combined risk perception')

################################

axs[1,0].set_ylabel('Decision update rate' )

axs[1,0].scatter(PT_high_combined_info_0, PT_high_d_update_0, marker='o', s = 20, alpha = 0.1, color="blue")
axs[1,0].scatter(PT_high_combined_info_1, PT_high_d_update_1, marker='o', s = 20, alpha = 0.1, color="red")

axs[1,1].scatter(PT_mid_combined_info_0, PT_mid_d_update_0, marker='o', s = 20, alpha = 0.1, color="blue")
axs[1,1].scatter(PT_mid_combined_info_1, PT_mid_d_update_1, marker='o', s = 20, alpha = 0.1, color="red")

axs[1,2].scatter(PT_low_combined_info_0, PT_low_d_update_0, marker='o', s = 20, alpha = 0.1, color="blue")
axs[1,2].scatter(PT_low_combined_info_1, PT_low_d_update_1, marker='o', s = 20, alpha = 0.1, color="red")


axs[1,0].set_xlabel('Combined risk perception')
axs[1,1].set_xlabel('Combined risk perception')
axs[1,2].set_xlabel('Combined risk perception')

################################

for i in [0,1]:
    for j in [0,1,2]:
        for pos in ['right', 'top', 'bottom', 'left']: 
            axs[i][j].spines[pos].set_visible(False)

        axs[i][j].set_ylim(-0.02,1.02)
        axs[i][j].set_xticks([0, 0.5, 1])  
        axs[i][j].set_yticks([0, 0.5, 1])  
    

# Create custom legend handles
handles = [plt.Line2D([], [], marker='o', markersize=7, color='red', linestyle='None', alpha=0.3),
          plt.Line2D([], [], marker='o', markersize=7, color='blue', linestyle='None', alpha=0.3)]

axs[0,2].legend(handles, ["Move","Don't move"], ncol=1, bbox_to_anchor=(1, 1) ,fontsize = "small", title = "Decision")

# fig.text(0.38, -0.02, 'Risk perception')

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(3, 3, figsize=(10, 7))

axs[0,0].set_ylabel('Observed Mobility' )
axs[0,0].set_title('High PT')
axs[0,0].scatter(PT_high_dt_0, PT_high_mobility_0, marker='o', s = 20, alpha = 0.1, color="blue")
axs[0,0].scatter(PT_high_dt_1, PT_high_mobility_1, marker='o', s = 20, alpha = 0.1, color="red")

axs[0,1].set_title('Mid PT')
axs[0,1].scatter(PT_mid_dt_0, PT_mid_mobility_0, marker='o', s = 20, alpha = 0.1, color="blue")
axs[0,1].scatter(PT_mid_dt_1, PT_mid_mobility_1, marker='o', s = 20, alpha = 0.1, color="red")

axs[0,2].set_title('Low PT')
axs[0,2].scatter(PT_low_dt_0, PT_low_mobility_0, marker='o', s = 20, alpha = 0.1, color="blue")
axs[0,2].scatter(PT_low_dt_1, PT_low_mobility_1, marker='o', s = 20, alpha = 0.1, color="red")


############################

axs[1,0].set_ylabel('Risk perception')
axs[1,0].scatter(PT_high_dt_0, PT_high_final_op_0, marker='o', s = 20, alpha = 0.1, color="blue")
axs[1,0].scatter(PT_high_dt_1, PT_high_final_op_1, marker='o', s = 20, alpha = 0.1, color="red")

axs[1,1].scatter(PT_mid_dt_0, PT_mid_final_op_0, marker='o', s = 20, alpha = 0.1, color="blue")
axs[1,1].scatter(PT_mid_dt_1, PT_mid_final_op_1, marker='o', s = 20, alpha = 0.1, color="red")

axs[1,2].scatter(PT_low_dt_0, PT_low_final_op_0, marker='o', s = 20, alpha = 0.1, color="blue")
axs[1,2].scatter(PT_low_dt_1, PT_low_final_op_1, marker='o', s = 20, alpha = 0.1, color="red")

#############################

axs[2,0].set_ylabel('Decision update rate')
axs[2,0].scatter(PT_high_dt_0, PT_high_d_update_0, marker='o', s = 20, alpha = 0.1, color="blue")
axs[2,0].scatter(PT_high_dt_1, PT_high_d_update_1, marker='o', s = 20, alpha = 0.1, color="red")

axs[2,1].scatter(PT_mid_dt_0, PT_mid_d_update_0, marker='o', s = 20, alpha = 0.1, color="blue")
axs[2,1].scatter(PT_mid_dt_1, PT_mid_d_update_1, marker='o', s = 20, alpha = 0.1, color="red")

axs[2,2].scatter(PT_low_dt_0, PT_low_d_update_0, marker='o', s = 20, alpha = 0.1, color="blue")
axs[2,2].scatter(PT_low_dt_1, PT_low_d_update_1, marker='o', s = 20, alpha = 0.1, color="red")


for i in [0,1,2]:
    for j in [0,1,2]:
        for pos in ['right', 'top', 'bottom', 'left']: 
            axs[i][j].spines[pos].set_visible(False)

        axs[i][j].set_ylim(-0.02,1.02)
        axs[i][j].set_xticks([0, 0.5, 1])  
        axs[i][j].set_yticks([0, 0.5, 1])  
    

# Create custom legend handles
handles = [plt.Line2D([], [], marker='o', markersize=7, color='red', linestyle='None', alpha=0.3),
          plt.Line2D([], [], marker='o', markersize=7, color='blue', linestyle='None', alpha=0.3)]

axs[1,2].legend(handles, ["Move","Don't move"], ncol=1, bbox_to_anchor=(1, 0.7) ,fontsize = "small", title = "Decision")

fig.text(0.38, -0.02, 'Risk-tolerance threshold')

plt.tight_layout()
plt.show()
