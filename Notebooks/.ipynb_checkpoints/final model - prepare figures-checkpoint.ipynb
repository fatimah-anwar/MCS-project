# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")

# %config InlineBackend.figure_format = 'retina'

# %%
results_folder = "Final_model_results"

# %% [markdown]
# ## Experiment 1

# %% [markdown]
# ## 1. overall model behaviour for different alpha values

# %%
exp1_100_iter = pd.read_csv(results_folder+"/ex1_batchrun_100_iteration.csv")

# %%
num_steps = len(exp1_100_iter['Step'].unique()) - 1

# %%
exp1_100_iter_alpah_0 = exp1_100_iter.query('alpha == 0 and iteration <= 50')
exp1_100_iter_alpah_02 = exp1_100_iter.query('alpha == 0.2 and iteration <= 50')
exp1_100_iter_alpah_05 = exp1_100_iter.query('alpha == 0.5 and iteration <= 50')
exp1_100_iter_alpah_08 = exp1_100_iter.query('alpha == 0.8 and iteration <= 50')
exp1_100_iter_alpah_1 = exp1_100_iter.query('alpha == 1 and iteration <= 50')

# %% [markdown]
# ### Mobility rate over time | 500 agents - 100 timesteps - 50 iterations

# %%
plt.figure(figsize=(4,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 


sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp1_100_iter_alpah_0.groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0$") 
sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp1_100_iter_alpah_02.groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.2$") 
sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp1_100_iter_alpah_05.groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.5$")  
sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp1_100_iter_alpah_08.groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.8$") 
sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp1_100_iter_alpah_1.groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 1$") 

plt.ylim(0,1)
plt.xlabel("Time step")
plt.ylabel("Mobility rate")
plt.legend(bbox_to_anchor=(1, .86), ncol=1)

plt.show()

# %%
exp1_50_iter = pd.read_csv(results_folder+"/ex1_batchrun_50_iteration_full_alpha_range.csv")

# %%
num_steps = len(exp1_50_iter['Step'].unique()) - 1
num_steps
# Out:
# 100

# %%
exp1_50_iter_alpah_0 = exp1_50_iter.query('alpha == 0')

exp1_50_iter_alpah_01 = exp1_50_iter.query('alpha == 0.1')
exp1_50_iter_alpah_02 = exp1_50_iter.query('alpha == 0.2')
exp1_50_iter_alpah_03 = exp1_50_iter.query('alpha == 0.3')
exp1_50_iter_alpah_04 = exp1_50_iter.query('alpha == 0.4')

exp1_50_iter_alpah_05 = exp1_50_iter.query('alpha == 0.5')

exp1_50_iter_alpah_06 = exp1_50_iter.query('alpha == 0.6 and mobility_rate < 0.6')
exp1_50_iter_alpah_07 = exp1_50_iter.query('alpha == 0.7')
exp1_50_iter_alpah_08 = exp1_50_iter.query('alpha == 0.8')
exp1_50_iter_alpah_09 = exp1_50_iter.query('alpha == 0.9')

exp1_50_iter_alpah_1 = exp1_50_iter.query('alpha == 1')

# %%
plt.figure(figsize=(4,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 


sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp1_50_iter_alpah_0.groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0$") 
sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp1_50_iter_alpah_02.groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.2$") 
# sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp1_50_iter_alpah_04.groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.4$") 
sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp1_50_iter_alpah_05.groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.5$")  
# sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp1_50_iter_alpah_06.groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.6$") 
sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp1_50_iter_alpah_08.groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.8$") 
sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp1_50_iter_alpah_1.groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 1$") 

plt.ylim(0,1)
plt.xlabel("Time step")
plt.ylabel("Agents' mobility rate")
plt.legend(bbox_to_anchor=(1, .86), ncol=1)

plt.show()

# %%
# plt.figure(figsize=(4,  3))
# for pos in ['right', 'top', 'bottom', 'left']: 
#     plt.gca().spines[pos].set_visible(False) 


# sns.lineplot(x = "Step" , y = "op_avg" , data = exp1_100_iter_alpah_0.groupby("Step")['op_avg'].mean().reset_index() )
# sns.lineplot(x = "Step" , y = "op_avg" , data = exp1_100_iter_alpah_02.groupby("Step")['op_avg'].mean().reset_index() ) 
# sns.lineplot(x = "Step" , y = "op_avg" , data = exp1_100_iter_alpah_05.groupby("Step")['op_avg'].mean().reset_index() )  
# sns.lineplot(x = "Step" , y = "op_avg" , data = exp1_100_iter_alpah_08.groupby("Step")['op_avg'].mean().reset_index() ) 
# sns.lineplot(x = "Step" , y = "op_avg" , data = exp1_100_iter_alpah_1.groupby("Step")['op_avg'].mean().reset_index() )

# plt.ylim(0,1)
# plt.xlabel("Time step")
# plt.ylabel("Average opinion")
# # plt.legend(bbox_to_anchor=(1, .86), ncol=1)

# plt.show()

# %%
# plt.figure(figsize=(4,  3))
# for pos in ['right', 'top', 'bottom', 'left']: 
#     plt.gca().spines[pos].set_visible(False) 

# # plt.hist(x = list(exp1_50_iter.query('Step == 100 and alpha == 0')['mobility_rate']) , alpha = 0.5 , label = r"$\alpha = 0$") 
# plt.hist(x = list(exp1_50_iter.query('Step == 100 and alpha == 0.2')['mobility_rate']) , alpha = 0.5 , label = r"$\alpha = 0.2$") 
# # plt.hist(x = list(exp1_50_iter.query('Step == 100 and alpha == 0.5')['mobility_rate']) , alpha = 0.5 , label = r"$\alpha = 0.5$") 
# plt.hist(x = list(exp1_50_iter.query('Step == 100 and alpha == 0.8')['mobility_rate']) , alpha = 0.5 , label = r"$\alpha = 0.8$") 
# # plt.hist(x = list(exp1_50_iter.query('Step == 100 and alpha == 1')['mobility_rate']) , alpha = 0.5 , label = r"$\alpha = 1$") 

# plt.xlabel("Final mobility rate")
# plt.ylabel("Frequency")

# plt.legend(bbox_to_anchor=(1, .86), ncol=1)

# plt.show()

# %% [markdown]
# ### final decsions as function of alpha | 500 agents - 100 timesteps - 50 iterations

# %%
plt.figure(figsize=(4,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

sns.lineplot(x = "alpha" , y = "mobility_rate" , data = exp1_50_iter.query('Step == 100').groupby('alpha')['mobility_rate'].mean().reset_index(), label = "mobility_rate") 
sns.lineplot(x = "alpha" , y = "stop_moving_rate" , data = exp1_50_iter.query('Step == 100').groupby('alpha')['stop_moving_rate'].mean().reset_index(), label = "stop_moving_rate") 

plt.ylim(-0.02,1)
plt.xlabel(r"$\alpha$")
plt.ylabel("")
# plt.legend(bbox_to_anchor=(1, .86), ncol=1)

plt.show()

# %%
exp1_100_iter.columns
# Out:
# Index(['RunId', 'iteration', 'Step', 'N', 'h', 'w', 'collect_agent_data',
#        'alpha', 'op_avg', 'combined_info_avg', 'moving', 'not_moving',
#        'mobility_rate', 'start_moving_count', 'stop_moving_count',
#        'start_moving_rate', 'stop_moving_rate', 'updated_decision_count',
#        'updated_decision_rate', 'communicatin_count', 'communication_rate'],
#       dtype='object')

# %%
plt.figure(figsize=(4,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

sns.lineplot(x = "alpha" , y = "mobility_rate" , data = exp1_100_iter.query('iteration < 50 and Step == 100').groupby('alpha')['mobility_rate'].mean().reset_index(), label = 'Mobility rate') 
sns.lineplot(x = "alpha" , y = "updated_decision_rate" , data = exp1_100_iter.query('iteration < 50 and Step == 100').groupby('alpha')['updated_decision_rate'].mean().reset_index(), label = "Decision update rate") 

plt.ylim(-0.02,1)
plt.xlabel(r"$\alpha$")
plt.ylabel("")

# plt.legend(bbox_to_anchor=(1.7, 0.65), ncol=1)

plt.show()

# %%
exp1_1_iter['decision_update_counter'] = (exp1_1_iter['move_counter'] + exp1_1_iter['stop_move_counter']) 

exp1_1_iter['decision_update_rate'] = exp1_1_iter['decision_update_counter'] / num_steps

# %% [markdown]
# ## 2. Details of the agents' behaviours in a single iteration

# %%
exp1_1_iter = pd.read_csv(results_folder+"/ex1_batchrun_single_iteration.csv")

# %%
num_agents = len(exp1_1_iter['AgentID'].unique())
num_steps = len(exp1_1_iter['Step'].unique()) - 1

# %%
exp1_1_iter['decision_update_rate'] = (exp1_1_iter['move_counter'] + exp1_1_iter['stop_move_counter']) / exp1_1_iter['Step']
exp1_1_iter['stop_move_rate'] = exp1_1_iter['stop_move_counter'] / exp1_1_iter['Step']

# %%
exp1_1_iter_alpah_0 = exp1_1_iter.query('alpha == 0')
exp1_1_iter_alpah_02 = exp1_1_iter.query('alpha == 0.2')
exp1_1_iter_alpah_05 = exp1_1_iter.query('alpha == 0.5')
exp1_1_iter_alpah_08 = exp1_1_iter.query('alpha == 0.8')
exp1_1_iter_alpah_1 = exp1_1_iter.query('alpha == 1')

# %%
plt.figure(figsize=(4,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 


plt.hist(x = list(exp1_1_iter_alpah_02.query('Step == 100')['old_opinion'])) 

plt.ylim(0, 120)
plt.xlim(0,1)
plt.xlabel("Final opinion")
plt.ylabel("Frequency")
# plt.legend(bbox_to_anchor=(1, .86), ncol=1)

plt.show()

# %%
plt.figure(figsize=(4,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 


plt.hist(x = list(exp1_1_iter_alpah_08.query('Step == 100')['old_opinion'])) 

plt.ylim(0, 120)
plt.xlim(0,1)
plt.xlabel("Final opinion")
plt.ylabel("Frequency")
# plt.legend(bbox_to_anchor=(1, .86), ncol=1)

plt.show()

# %%
exp1_1_iter_alpah_05.query("AgentID == 2")[['opinion', 'old_opinion', 'observed_mobility', 'online_info', 'offline_info', 'combined_info',
       'decision_th','decision']]
# Out:
#          opinion  old_opinion  observed_mobility  online_info  offline_info  \
# 101002  0.872661     0.872661           0.000000     0.000000      0.000000
# 101502  0.686330     0.872661           0.500000     0.436330      0.250000
# 102002  0.570438     0.686330           0.545455     0.343165      0.227273
# 102502  0.203987     0.227343           0.500000     0.113672      0.250000
# 103002  0.375221     0.250442           0.500000     0.125221      0.250000
# ...          ...          ...                ...          ...           ...
# 149002  0.634210     0.359330           0.090909     0.179665      0.454545
# 149502  0.602088     0.340540           0.136364     0.170270      0.431818
# 150002  0.631072     0.353054           0.090909     0.176527      0.454545
# 150502  0.747354     0.631072           0.136364     0.315536      0.431818
# 151002  0.374128     0.402157           0.090909     0.201078      0.454545
#
#         combined_info  decision_th  decision
# ...

# %%
exp1_1_iter_alpah_0.query("AgentID == 0")[["opinion","observed_mobility","online_info","offline_info", "combined_info","decision_th","decision"]]
# Out:
#         opinion  observed_mobility  online_info  offline_info  combined_info  \
# 0      0.324238           0.000000          0.0      0.000000       0.000000
# 500    0.722222           0.277778          0.0      0.722222       0.722222
# 1000   0.777778           0.222222          0.0      0.777778       0.777778
# 1500   0.888889           0.111111          0.0      0.888889       0.888889
# 2000   1.000000           0.000000          0.0      1.000000       1.000000
# ...         ...                ...          ...           ...            ...
# 48000  1.000000           0.000000          0.0      1.000000       1.000000
# 48500  1.000000           0.000000          0.0      1.000000       1.000000
# 49000  1.000000           0.000000          0.0      1.000000       1.000000
# 49500  1.000000           0.000000          0.0      1.000000       1.000000
# 50000  1.000000           0.000000          0.0      1.000000       1.000000
#
#        decision_th  decision
# ...

# %% [markdown]
# ### observed mobility vs. opinion (final step)

# %%
alpha_0_final_op_0 = list(exp1_1_iter_alpah_0.tail(num_agents).query("decision == 0")['old_opinion'])
alpha_0_final_op_1 = list(exp1_1_iter_alpah_0.tail(num_agents).query("decision == 1")['old_opinion'])

alpha_0_mobility_0 = list(exp1_1_iter_alpah_0.tail(num_agents).query("decision == 0")['observed_mobility'])
alpha_0_mobility_1 = list(exp1_1_iter_alpah_0.tail(num_agents).query("decision == 1")['observed_mobility'])

alpha_0_dt_0 = list(exp1_1_iter_alpah_0.tail(num_agents).query("decision == 0")['decision_th'])
alpha_0_dt_1 = list(exp1_1_iter_alpah_0.tail(num_agents).query("decision == 1")['decision_th'])

alpha_0_I_0 = list(exp1_1_iter_alpah_0.tail(num_agents).query("decision == 0")['combined_info'])
alpha_0_I_1 = list(exp1_1_iter_alpah_0.tail(num_agents).query("decision == 1")['combined_info'])

# alpha_0_stop_move_0 = list(exp1_1_iter_alpah_0.tail(num_agents).query("decision == 0")['stop_move_rate'])
# alpha_0_stop_move_1 = list(exp1_1_iter_alpah_0.tail(num_agents).query("decision == 1")['stop_move_rate'])

alpha_0_update_0 = list(exp1_1_iter_alpah_0.tail(num_agents).query("decision == 0")['decision_update_rate'])
alpha_0_update_1 = list(exp1_1_iter_alpah_0.tail(num_agents).query("decision == 1")['decision_update_rate'])


###########################

alpha_05_final_op_0 = list(exp1_1_iter_alpah_05.tail(num_agents).query("decision == 0")['old_opinion'])
alpha_05_final_op_1 = list(exp1_1_iter_alpah_05.tail(num_agents).query("decision == 1")['old_opinion'])

alpha_05_mobility_0 = list(exp1_1_iter_alpah_05.tail(num_agents).query("decision == 0")['observed_mobility'])
alpha_05_mobility_1 = list(exp1_1_iter_alpah_05.tail(num_agents).query("decision == 1")['observed_mobility'])

alpha_05_dt_0 = list(exp1_1_iter_alpah_05.tail(num_agents).query("decision == 0")['decision_th'])
alpha_05_dt_1 = list(exp1_1_iter_alpah_05.tail(num_agents).query("decision == 1")['decision_th'])

alpha_05_I_0 = list(exp1_1_iter_alpah_05.tail(num_agents).query("decision == 0")['combined_info'])
alpha_05_I_1 = list(exp1_1_iter_alpah_05.tail(num_agents).query("decision == 1")['combined_info'])

# alpha_05_stop_move_0 = list(exp1_1_iter_alpah_05.tail(num_agents).query("decision == 0")['stop_move_rate'])
# alpha_05_stop_move_1 = list(exp1_1_iter_alpah_05.tail(num_agents).query("decision == 1")['stop_move_rate'])

alpha_05_update_0 = list(exp1_1_iter_alpah_05.tail(num_agents).query("decision == 0")['decision_update_rate'])
alpha_05_update_1 = list(exp1_1_iter_alpah_05.tail(num_agents).query("decision == 1")['decision_update_rate'])

#############################

alpha_1_final_op_0 = list(exp1_1_iter_alpah_1.tail(num_agents).query("decision == 0")['old_opinion'])
alpha_1_final_op_1 = list(exp1_1_iter_alpah_1.tail(num_agents).query("decision == 1")['old_opinion'])

alpha_1_mobility_0 = list(exp1_1_iter_alpah_1.tail(num_agents).query("decision == 0")['observed_mobility'])
alpha_1_mobility_1 = list(exp1_1_iter_alpah_1.tail(num_agents).query("decision == 1")['observed_mobility'])

alpha_1_dt_0 = list(exp1_1_iter_alpah_1.tail(num_agents).query("decision == 0")['decision_th'])
alpha_1_dt_1 = list(exp1_1_iter_alpah_1.tail(num_agents).query("decision == 1")['decision_th'])

alpha_1_I_0 = list(exp1_1_iter_alpah_1.tail(num_agents).query("decision == 0")['combined_info'])
alpha_1_I_1 = list(exp1_1_iter_alpah_1.tail(num_agents).query("decision == 1")['combined_info'])

# alpha_1_stop_move_0 = list(exp1_1_iter_alpah_1.tail(num_agents).query("decision == 0")['stop_move_rate'])
# alpha_1_stop_move_1 = list(exp1_1_iter_alpah_1.tail(num_agents).query("decision == 1")['stop_move_rate'])

alpha_1_update_0 = list(exp1_1_iter_alpah_1.tail(num_agents).query("decision == 0")['decision_update_rate'])
alpha_1_update_1 = list(exp1_1_iter_alpah_1.tail(num_agents).query("decision == 1")['decision_update_rate'])

# %%
fig, axs = plt.subplots(2, 3, figsize=(9, 4.5))



axs[0,0].set_title(r"$\alpha = 0$")
axs[0,1].set_title(r"$\alpha = 0.5$")
axs[0,2].set_title(r"$\alpha = 1$")


axs[0,0].scatter(alpha_0_final_op_0, alpha_0_mobility_0, marker='o', s = 25, alpha = 0.1, color="blue")
axs[0,1].scatter(alpha_05_final_op_0, alpha_05_mobility_0, marker='o', s = 25, alpha = 0.1, color="blue")
axs[0,2].scatter(alpha_1_final_op_0, alpha_1_mobility_0, marker='o', s = 25, alpha = 0.1, color="blue")

axs[1,0].scatter(alpha_0_final_op_1, alpha_0_mobility_1, marker='o', s = 25, alpha = 0.1, color="red")
axs[1,1].scatter(alpha_05_final_op_1, alpha_05_mobility_1, marker='o', s = 25, alpha = 0.1, color="red")
axs[1,2].scatter(alpha_1_final_op_1, alpha_1_mobility_1, marker='o', s = 25, alpha = 0.1, color="red")

for i in [0,1]:
    for j in [0,1,2]:
        for pos in ['right', 'top', 'bottom', 'left']: 
            axs[i][j].spines[pos].set_visible(False)

        axs[i][j].set_ylim(-0.02,1.02)
        axs[i][j].set_xticks([0, 0.5, 1])  
        axs[i][j].set_yticks([0, 0.5, 1])  


axs[0][0].set_xticklabels([])
axs[0][1].set_xticklabels([])
axs[0][2].set_xticklabels([])


axs[0][1].set_yticklabels([])
axs[0][2].set_yticklabels([])
axs[1][1].set_yticklabels([])
axs[1][2].set_yticklabels([])


# Create custom legend handles
handles = [plt.Line2D([], [], marker='o', markersize=7, color='blue', linestyle='None', alpha=0.3),
           plt.Line2D([], [], marker='o', markersize=7, color='red', linestyle='None', alpha=0.3)]

axs[0,2].legend(handles, ["Don't move (0)", "Move (1)"], ncol=1, bbox_to_anchor=(1.8, 1), loc = "best" ,fontsize = "small", title = "Decision (X)")


# X axis
fig.text(0.43, -0.01, 'Opinion (O)', ha='center')
# Y axis
fig.text(-0.01, 0.5, 'Observed Mobility (M)', va='center', rotation='vertical')


plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, 3, figsize=(9, 4.5))



axs[0,0].set_title(r"$\alpha = 0$")
axs[0,1].set_title(r"$\alpha = 0.5$")
axs[0,2].set_title(r"$\alpha = 1$")

# axs[0,0].set_ylabel('Risk percpetion (I)' )

axs[0,0].scatter(alpha_0_dt_0  , alpha_0_I_0 ,  marker='o', s = 25, alpha = 0.1, color="blue")
axs[0,1].scatter(alpha_05_dt_0 , alpha_05_I_0 ,  marker='o', s = 25, alpha = 0.1, color="blue")
axs[0,2].scatter(alpha_1_dt_0  , alpha_1_I_0 , marker='o', s = 25, alpha = 0.1, color="blue")

# axs[0,0].scatter(alpha_0_dt_1  , alpha_0_I_1 ,  marker='o', s = 15, alpha = 0.1, color="red")
# axs[0,1].scatter(alpha_05_dt_1 , alpha_05_I_1 ,  marker='o', s = 15, alpha = 0.1, color="red")
# axs[0,2].scatter(alpha_1_dt_1  , alpha_1_I_1 , marker='o', s = 15, alpha = 0.1, color="red")

# axs[1,0].set_ylabel('Risk percpetion (I)' )

axs[1,0].scatter(alpha_0_dt_1  , alpha_0_I_1 ,  marker='o', s = 25, alpha = 0.1, color="red")
axs[1,1].scatter(alpha_05_dt_1 , alpha_05_I_1 ,  marker='o', s = 25, alpha = 0.1, color="red")
axs[1,2].scatter(alpha_1_dt_1  , alpha_1_I_1 , marker='o', s = 25, alpha = 0.1, color="red")


# axs[1,0].set_xlabel(r"$\tau$")
# axs[1,1].set_xlabel(r"$\tau$")
# axs[1,2].set_xlabel(r"$\tau$")


for i in [0,1]:
    for j in [0,1,2]:
        for pos in ['right', 'top', 'bottom', 'left']: 
            axs[i][j].spines[pos].set_visible(False)

        axs[i][j].set_ylim(-0.02,1.02)
        axs[i][j].set_xticks([0, 0.5, 1])  
        axs[i][j].set_yticks([0, 0.5, 1])  
    

axs[0][0].set_xticklabels([])
axs[0][1].set_xticklabels([])
axs[0][2].set_xticklabels([])


axs[0][1].set_yticklabels([])
axs[0][2].set_yticklabels([])
axs[1][1].set_yticklabels([])
axs[1][2].set_yticklabels([])


# Create custom legend handles
handles = [plt.Line2D([], [], marker='o', markersize=7, color='blue', linestyle='None', alpha=0.3),
           plt.Line2D([], [], marker='o', markersize=7, color='red', linestyle='None', alpha=0.3)]

axs[0,2].legend(handles, ["Don't move (0)", "Move (1)"], ncol=1, bbox_to_anchor=(1.8, 1), loc = "best" ,fontsize = "small", title = "Decision (X)")


# X axis
fig.text(0.43, -0.01, 'Risk-tolerance threshold ('+r"$\tau$"+")", ha='center')
# Y axis
fig.text(-0.01, 0.5, 'Risk percpetion (I)', va='center', rotation='vertical')


# fig.text(0.38, -0.02, 'Risk-tolerance threshold ('+r"$\tau$"+")")

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, 3, figsize=(9, 4.5))


axs[0,0].set_title(r"$\alpha = 0$")
axs[0,1].set_title(r"$\alpha = 0.5$")
axs[0,2].set_title(r"$\alpha = 1$")

axs[0,0].scatter(alpha_0_dt_0  , alpha_0_update_0 , marker='o', s = 25, alpha = 0.1, color="blue")
axs[0,1].scatter(alpha_05_dt_0 , alpha_05_update_0 , marker='o', s = 25, alpha = 0.1, color="blue")
axs[0,2].scatter(alpha_1_dt_0 , alpha_1_update_0 , marker='o', s = 25, alpha = 0.1, color="blue")

axs[1,0].scatter(alpha_0_dt_1  , alpha_0_update_1 , marker='o', s = 25, alpha = 0.1, color="red")
axs[1,1].scatter(alpha_05_dt_1 , alpha_05_update_1 , marker='o', s = 25, alpha = 0.1, color="red")
axs[1,2].scatter(alpha_1_dt_1 , alpha_1_update_1 , marker='o', s = 25, alpha = 0.1, color="red")


for i in [0,1]:
    for j in [0,1,2]:
        for pos in ['right', 'top', 'bottom', 'left']: 
            axs[i][j].spines[pos].set_visible(False)

        axs[i][j].set_ylim(-0.02,1.02)
        axs[i][j].set_xticks([0, 0.5, 1])  
        axs[i][j].set_yticks([0, 0.5, 1])  
    

axs[0][0].set_xticklabels([])
axs[0][1].set_xticklabels([])
axs[0][2].set_xticklabels([])


axs[0][1].set_yticklabels([])
axs[0][2].set_yticklabels([])
axs[1][1].set_yticklabels([])
axs[1][2].set_yticklabels([])


# Create custom legend handles
handles = [plt.Line2D([], [], marker='o', markersize=7, color='blue', linestyle='None', alpha=0.3),
           plt.Line2D([], [], marker='o', markersize=7, color='red', linestyle='None', alpha=0.3)]

axs[0,2].legend(handles, ["Don't move (0)", "Move (1)"], ncol=1, bbox_to_anchor=(1.8, 1), loc = "best" ,fontsize = "small", title = "Decision (X)")


# X axis
fig.text(0.43, -0.01, 'Risk-tolerance threshold ('+r"$\tau$"+")", ha='center')
# Y axis
fig.text(-0.01, 0.5, 'Decision update rate', va='center', rotation='vertical')


plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, 3, figsize=(9, 4.5))

axs[0,0].set_title(r"$\alpha = 0$")
axs[0,1].set_title(r"$\alpha = 0.5$")
axs[0,2].set_title(r"$\alpha = 1$")


axs[0,0].scatter(alpha_0_I_0  , alpha_0_update_0 , marker='o', s = 25, alpha = 0.1, color="blue")
axs[0,1].scatter(alpha_05_I_0 , alpha_05_update_0 , marker='o', s = 25, alpha = 0.1, color="blue")
axs[0,2].scatter(alpha_1_I_0 , alpha_1_update_0 , marker='o', s = 25, alpha = 0.1, color="blue")

axs[1,0].scatter(alpha_0_I_1  , alpha_0_update_1 , marker='o', s = 25, alpha = 0.1, color="red")
axs[1,1].scatter(alpha_05_I_1 , alpha_05_update_1 , marker='o', s = 25, alpha = 0.1, color="red")
axs[1,2].scatter(alpha_1_I_1 , alpha_1_update_1 , marker='o', s = 25, alpha = 0.1, color="red")


for i in [0,1]:
    for j in [0,1,2]:
        for pos in ['right', 'top', 'bottom', 'left']: 
            axs[i][j].spines[pos].set_visible(False)

        axs[i][j].set_ylim(-0.02,1.02)
        axs[i][j].set_xticks([0, 0.5, 1])  
        axs[i][j].set_yticks([0, 0.5, 1])  
    

axs[0][0].set_xticklabels([])
axs[0][1].set_xticklabels([])
axs[0][2].set_xticklabels([])


axs[0][1].set_yticklabels([])
axs[0][2].set_yticklabels([])
axs[1][1].set_yticklabels([])
axs[1][2].set_yticklabels([])


# Create custom legend handles
handles = [plt.Line2D([], [], marker='o', markersize=7, color='blue', linestyle='None', alpha=0.3),
           plt.Line2D([], [], marker='o', markersize=7, color='red', linestyle='None', alpha=0.3)]

axs[0,2].legend(handles, ["Don't move (0)", "Move (1)"], ncol=1, bbox_to_anchor=(1.8, 1), loc = "best" ,fontsize = "small", title = "Decision (X)")


# X axis
fig.text(0.43, -0.01, 'Risk percpetion (I)', ha='center')
# Y axis
fig.text(-0.01, 0.5, 'Decision update rate', va='center', rotation='vertical')


plt.tight_layout()
plt.show()

# %%
# fig, axs = plt.subplots(2, 3, figsize=(9, 4.5))



# axs[0,0].set_title(r"$\alpha = 0$")
# axs[0,1].set_title(r"$\alpha = 0.5$")
# axs[0,2].set_title(r"$\alpha = 1$")

# axs[0,0].set_ylabel('Risk percpetion (I)' )

# # axs[0,0].scatter(alpha_0_dt_0  , alpha_0_I_0 ,  marker='o', s = 15, alpha = 0.1, color="blue")
# # axs[0,1].scatter(alpha_05_dt_0 , alpha_05_I_0 ,  marker='o', s = 15, alpha = 0.1, color="blue")
# # axs[0,2].scatter(alpha_1_dt_0  , alpha_1_I_0 , marker='o', s = 15, alpha = 0.1, color="blue")

# axs[0,0].scatter(alpha_0_dt_1  , alpha_0_I_1 ,  marker='o', s = 15, alpha = 0.1, color="red")
# axs[0,1].scatter(alpha_05_dt_1 , alpha_05_I_1 ,  marker='o', s = 15, alpha = 0.1, color="red")
# axs[0,2].scatter(alpha_1_dt_1  , alpha_1_I_1 , marker='o', s = 15, alpha = 0.1, color="red")

# ################################

# axs[1,0].set_ylabel('stop_move_rate' )

# # axs[1,0].scatter(alpha_0_dt_0  , alpha_0_stop_move_0 , marker='o', s = 15, alpha = 0.1, color="blue")
# # axs[1,1].scatter(alpha_05_dt_0 , alpha_05_stop_move_0 , marker='o', s = 15, alpha = 0.1, color="blue")
# # axs[1,2].scatter(alpha_1_dt_0 , alpha_1_stop_move_0 , marker='o', s = 15, alpha = 0.1, color="blue")

# axs[1,0].scatter(alpha_0_dt_1  , alpha_0_stop_move_1 , marker='o', s = 15, alpha = 0.1, color="red")
# axs[1,1].scatter(alpha_05_dt_1 , alpha_05_stop_move_1 , marker='o', s = 15, alpha = 0.1, color="red")
# axs[1,2].scatter(alpha_1_dt_1 , alpha_1_stop_move_1 , marker='o', s = 15, alpha = 0.1, color="red")



# axs[1,0].set_xlabel('Risk-tolerance threshold')
# axs[1,1].set_xlabel('Risk-tolerance threshold')
# axs[1,2].set_xlabel('Risk-tolerance threshold')


# for i in [0,1]:
#     for j in [0,1,2]:
#         for pos in ['right', 'top', 'bottom', 'left']: 
#             axs[i][j].spines[pos].set_visible(False)

#         axs[i][j].set_ylim(-0.02,1.02)
#         axs[i][j].set_xticks([0, 0.5, 1])  
#         axs[i][j].set_yticks([0, 0.5, 1])  
    

# # Create custom legend handles
# handles = [plt.Line2D([], [], marker='o', markersize=7, color='red', linestyle='None', alpha=0.3),
#           plt.Line2D([], [], marker='o', markersize=7, color='blue', linestyle='None', alpha=0.3)]

# axs[0,2].legend(handles, ["Move (1)","Don't move (0)"], ncol=1, bbox_to_anchor=(2, 1), loc = "best" ,fontsize = "small", title = "Decision (X)")

# # fig.text(0.38, -0.02, 'Risk perception')

# plt.tight_layout()
# plt.show()

# %% [markdown]
# ### alpha = 0

# %%
# # figure format 
# plt.figure(figsize=(4,  3))
# for pos in ['right', 'top', 'bottom', 'left']: 
#     plt.gca().spines[pos].set_visible(False) 

# # prepare data

# # plot 
# plt.scatter(x1, y1, marker='o', s = 30, alpha = 0.1, color="blue" ,label = "0")
# plt.scatter(x2, y2, marker='o', s = 30, alpha = 0.1, color="red" ,label = "1")

# plt.xlabel('Opinions')
# plt.ylabel('Observed mobility')

# # # Create custom legend handles with higher opacity
# # handles = [plt.Line2D([], [], marker='o', markersize=7, color='red', linestyle='None', alpha=0.3),
# #           plt.Line2D([], [], marker='o', markersize=7, color='blue', linestyle='None', alpha=0.3)]

# # # Plot legend with custom handles and labels
# # plt.legend(handles, ['Non-moving agents', 'Moving agents'], ncol=2 
# #           , bbox_to_anchor=(0.85, -0.45, 0.2, 0.2))

# plt.show()

# %%
# # figure format 
# plt.figure(figsize=(4,  3))
# for pos in ['right', 'top', 'bottom', 'left']: 
#     plt.gca().spines[pos].set_visible(False) 

# # prepare data
# x1 = list(exp1_1_iter_alpah_0.tail(num_agents).query("decision == 0")['decision_th'])
# y1 = list(exp1_1_iter_alpah_0.tail(num_agents).query("decision == 0")['combined_info'])

# x2 = list(exp1_1_iter_alpah_0.tail(num_agents).query("decision == 1")['decision_th'])
# y2 = list(exp1_1_iter_alpah_0.tail(num_agents).query("decision == 1")['combined_info'])

# # plot 
# plt.scatter(x1, y1, marker='o', s = 30, alpha = 0.1, color="blue" ,label = "0")
# plt.scatter(x2, y2, marker='o', s = 30, alpha = 0.1, color="red" ,label = "1")


# plt.xlabel('Risk-tolerance threshold')
# plt.ylabel('Risk Perception (combined info)')

# # # Create custom legend handles with higher opacity
# # handles = [plt.Line2D([], [], marker='o', markersize=5, color='red', linestyle='None', alpha=0.3),
# #           plt.Line2D([], [], marker='o', markersize=5, color='blue', linestyle='None', alpha=0.3)]

# # # Plot legend with custom handles and labels
# # plt.legend(handles, ['Move', 'Not move'], bbox_to_anchor=(1, 0.75), ncol=1, title="Decision")

# # # plt.legend(title = "Decision", bbox_to_anchor=(1, 1), ncol=1)

# plt.show()

# %%
# # figure format 
# plt.figure(figsize=(4,  3))
# for pos in ['right', 'top', 'bottom', 'left']: 
#     plt.gca().spines[pos].set_visible(False) 

# # prepare data
# x1 = list(exp1_1_iter_alpah_0.tail(num_agents).query("decision == 0")['decision_th'])
# y1 = list(exp1_1_iter_alpah_0.tail(num_agents).query("decision == 0")['stop_move_rate'])

# x2 = list(exp1_1_iter_alpah_0.tail(num_agents).query("decision == 1")['decision_th'])
# y2 = list(exp1_1_iter_alpah_0.tail(num_agents).query("decision == 1")['stop_move_rate'])

# # plot 
# plt.scatter(x1, y1, marker='o', s = 30, alpha = 0.1, color="blue" ,label = "0")
# plt.scatter(x2, y2, marker='o', s = 30, alpha = 0.1, color="red" ,label = "1")


# plt.xlabel('Risk-tolerance threshold')
# plt.ylabel('stop_move_rate')
# # plt.ylim(-0.02,1.2)

# plt.show()

# %% [markdown]
# ## Experiment 2
#
# ### 1. Risk sensitivity (R = 0 , 1, 2)

# %%
exp2_R_50_iter = pd.read_csv(results_folder+"/ex2_1_R_batchrun_50_iteration.csv")

# %%
plt.figure(figsize=(4,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 


sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_R_50_iter.query('R == 2 and alpha == 0').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0$") 
sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_R_50_iter.query('R == 2 and alpha == 0.2').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.2$") 
sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_R_50_iter.query('R == 2 and alpha == 0.5').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.5$")  
sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_R_50_iter.query('R == 2 and alpha == 0.8').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.8$") 
sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_R_50_iter.query('R == 2 and alpha == 1').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 1$") 

plt.ylim(0,1)
plt.xlabel("Time step")
plt.ylabel("Mobility rate")
plt.legend(bbox_to_anchor=(1, .86), ncol=1)

plt.show()

# %%
plt.figure(figsize=(4,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

sns.lineplot(x = "alpha" , y = "mobility_rate" , data = exp2_R_50_iter.query('R == 2 and Step == 100').groupby('alpha')['mobility_rate'].mean().reset_index(), label = 'Mobility rate') 
sns.lineplot(x = "alpha" , y = "updated_decision_rate" , data = exp2_R_50_iter.query('R == 2 and Step == 100').groupby('alpha')['updated_decision_rate'].mean().reset_index(), label = "Decision update rate") 

plt.ylim(-0.02,1)
plt.xlabel(r"$\alpha$")
plt.ylabel("")

# plt.legend(bbox_to_anchor=(1.7, 0.65), ncol=1)

plt.show()

# %%
plt.figure(figsize=(4,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 


sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_R_50_iter.query('R == 1 and alpha == 0').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0$") 
sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_R_50_iter.query('R == 1 and alpha == 0.2').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.2$") 
sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_R_50_iter.query('R == 1 and alpha == 0.5').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.5$")  
sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_R_50_iter.query('R == 1 and alpha == 0.8').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.8$") 
sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_R_50_iter.query('R == 1 and alpha == 1').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 1$") 

plt.ylim(0,1)
plt.xlabel("Time step")
plt.ylabel("Mobility rate")
plt.legend(bbox_to_anchor=(1, .86), ncol=1)

plt.show()

# %%
plt.figure(figsize=(4,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

sns.lineplot(x = "alpha" , y = "mobility_rate" , data = exp2_R_50_iter.query('R == 1 and Step == 100').groupby('alpha')['mobility_rate'].mean().reset_index(), label = 'Mobility rate') 
sns.lineplot(x = "alpha" , y = "updated_decision_rate" , data = exp2_R_50_iter.query('R == 1 and Step == 100').groupby('alpha')['updated_decision_rate'].mean().reset_index(), label = "Decision update rate") 

plt.ylim(-0.02,1)
plt.xlabel(r"$\alpha$")
plt.ylabel("")

# plt.legend(bbox_to_anchor=(1.7, 0.65), ncol=1)

plt.show()

# %%
plt.figure(figsize=(4,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 


sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_R_50_iter.query('R == 0 and alpha == 0').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0$") 
sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_R_50_iter.query('R == 0 and alpha == 0.2').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.2$") 
sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_R_50_iter.query('R == 0 and alpha == 0.5').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.5$")  
sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_R_50_iter.query('R == 0 and alpha == 0.8').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.8$") 
sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_R_50_iter.query('R == 0 and alpha == 1').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 1$") 

plt.ylim(0,1)
plt.xlabel("Time step")
plt.ylabel("Mobility rate")
plt.legend(bbox_to_anchor=(1, .86), ncol=1)

plt.show()

# %%
plt.figure(figsize=(4,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

sns.lineplot(x = "alpha" , y = "mobility_rate" , data = exp2_R_50_iter.query('R == 0 and Step == 100').groupby('alpha')['mobility_rate'].mean().reset_index(), label = 'Mobility rate') 
sns.lineplot(x = "alpha" , y = "updated_decision_rate" , data = exp2_R_50_iter.query('R == 0 and Step == 100').groupby('alpha')['updated_decision_rate'].mean().reset_index(), label = "Decision update rate") 

plt.ylim(-0.02,1)
plt.xlabel(r"$\alpha$")
plt.ylabel("")

# plt.legend(bbox_to_anchor=(1.7, 0.65), ncol=1)

plt.show()

# %%
exp2_R_1_iter = pd.read_csv(results_folder+"/ex2_1_R_batchrun_single_iteration.csv")

# %%
num_agents = len(exp1_1_iter['AgentID'].unique())
num_steps = len(exp1_1_iter['Step'].unique()) - 1

# %% [markdown]
# ## R = 2

# %%
exp2_R_2_alpah_0 = exp2_R_1_iter.query('alpha == 0 and R == 2')
exp2_R_2_alpah_02 = exp2_R_1_iter.query('alpha == 0.2 and R == 2')
exp2_R_2_alpah_05 = exp2_R_1_iter.query('alpha == 0.5 and R == 2')
exp2_R_2_alpah_08 = exp2_R_1_iter.query('alpha == 0.8 and R == 2')
exp2_R_2_alpah_1 = exp2_R_1_iter.query('alpha == 1 and R == 2')

# %% [markdown]
# ### risk perception

# %%
plt.figure(figsize=(4,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

# prepare data
x1 = list(exp2_R_2_alpah_1.tail(num_agents).query("decision == 0")['decision_th'])
y1 = list(exp2_R_2_alpah_1.tail(num_agents).query("decision == 0")['combined_info'])

x2 = list(exp2_R_2_alpah_1.tail(num_agents).query("decision == 1")['decision_th'])
y2 = list(exp2_R_2_alpah_1.tail(num_agents).query("decision == 1")['combined_info'])

# plot 
plt.scatter(x1, y1, marker='o', s = 30, alpha = 0.1, color="blue" ,label = "0")
plt.scatter(x2, y2, marker='o', s = 30, alpha = 0.1, color="red" ,label = "1")

plt.xlabel('Risk-tolerance threshold')
plt.ylabel('Risk Perception (opinions)')

# plt.xlim(0,1)
plt.ylim(0,1.02)
plt.show()

# %%
plt.figure(figsize=(4,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

# prepare data
x1 = list(exp2_R_2_alpah_05.tail(num_agents).query("decision == 0")['decision_th'])
y1 = list(exp2_R_2_alpah_05.tail(num_agents).query("decision == 0")['combined_info'])

x2 = list(exp2_R_2_alpah_05.tail(num_agents).query("decision == 1")['decision_th'])
y2 = list(exp2_R_2_alpah_05.tail(num_agents).query("decision == 1")['combined_info'])

# plot 
plt.scatter(x1, y1, marker='o', s = 30, alpha = 0.1, color="blue" ,label = "0")
plt.scatter(x2, y2, marker='o', s = 30, alpha = 0.1, color="red" ,label = "1")

plt.xlabel('Risk-tolerance threshold')
plt.ylabel('Risk Perception (opinions)')

# plt.xlim(0,1)
plt.ylim(0,1.02)
plt.show()

# %% [markdown]
# ### observed mobility

# %%
plt.figure(figsize=(4,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

# prepare data
x1 = list(exp2_R_2_alpah_1.tail(num_agents).query("decision == 0")['decision_th'])
y1 = list(exp2_R_2_alpah_1.tail(num_agents).query("decision == 0")['observed_mobility'])

x2 = list(exp2_R_2_alpah_1.tail(num_agents).query("decision == 1")['decision_th'])
y2 = list(exp2_R_2_alpah_1.tail(num_agents).query("decision == 1")['observed_mobility'])

# plot 
plt.scatter(x1, y1, marker='o', s = 30, alpha = 0.1, color="blue" ,label = "0")
plt.scatter(x2, y2, marker='o', s = 30, alpha = 0.1, color="red" ,label = "1")

plt.xlabel('Risk-tolerance threshold')
plt.ylabel('Observed mobility')

# plt.xlim(0,1)
plt.ylim(-0.02,1.02)
plt.show()

# %%
plt.figure(figsize=(4,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

# prepare data
x1 = list(exp2_R_2_alpah_05.tail(num_agents).query("decision == 0")['decision_th'])
y1 = list(exp2_R_2_alpah_05.tail(num_agents).query("decision == 0")['observed_mobility'])

x2 = list(exp2_R_2_alpah_05.tail(num_agents).query("decision == 1")['decision_th'])
y2 = list(exp2_R_2_alpah_05.tail(num_agents).query("decision == 1")['observed_mobility'])

# plot 
plt.scatter(x1, y1, marker='o', s = 30, alpha = 0.1, color="blue" ,label = "0")
plt.scatter(x2, y2, marker='o', s = 30, alpha = 0.1, color="red" ,label = "1")

plt.xlabel('Risk-tolerance threshold')
plt.ylabel('Observed mobility')

# plt.xlim(0,1)
plt.ylim(-0.02,1.02)
plt.show()

# %%
plt.figure(figsize=(4,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

# prepare data
x1 = list(exp2_R_2_alpah_0.tail(num_agents).query("decision == 0")['decision_th'])
y1 = list(exp2_R_2_alpah_0.tail(num_agents).query("decision == 0")['combined_info'])

x2 = list(exp2_R_2_alpah_0.tail(num_agents).query("decision == 1")['decision_th'])
y2 = list(exp2_R_2_alpah_0.tail(num_agents).query("decision == 1")['combined_info'])

# plot 
plt.scatter(x1, y1, marker='o', s = 30, alpha = 0.1, color="blue" ,label = "0")
plt.scatter(x2, y2, marker='o', s = 30, alpha = 0.1, color="red" ,label = "1")

plt.xlabel('Risk-tolerance threshold')
plt.ylabel('Risk Perception (opinions)')

# plt.xlim(0,1)
# plt.ylim(0.02,1.02)
plt.show()

# %% [markdown]
# ## R = 1

# %%
exp2_R_1_alpah_0 = exp2_R_1_iter.query('alpha == 0 and R == 1')
exp2_R_1_alpah_02 = exp2_R_1_iter.query('alpha == 0.2 and R == 1')
exp2_R_1_alpah_05 = exp2_R_1_iter.query('alpha == 0.5 and R == 1')
exp2_R_1_alpah_08 = exp2_R_1_iter.query('alpha == 0.8 and R == 1')
exp2_R_1_alpah_1 = exp2_R_1_iter.query('alpha == 1 and R == 1')

# %% [markdown]
# ### risk perception

# %%
plt.figure(figsize=(4,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

# prepare data
x1 = list(exp2_R_1_alpah_1.tail(num_agents).query("decision == 0")['decision_th'])
y1 = list(exp2_R_1_alpah_1.tail(num_agents).query("decision == 0")['combined_info'])

x2 = list(exp2_R_1_alpah_1.tail(num_agents).query("decision == 1")['decision_th'])
y2 = list(exp2_R_1_alpah_1.tail(num_agents).query("decision == 1")['combined_info'])

# plot 
plt.scatter(x1, y1, marker='o', s = 30, alpha = 0.1, color="blue" ,label = "0")
plt.scatter(x2, y2, marker='o', s = 30, alpha = 0.1, color="red" ,label = "1")

plt.xlabel('Risk-tolerance threshold')
plt.ylabel('Risk Perception (opinions)')

# plt.xlim(0,1)
plt.ylim(0,1.02)
plt.show()

# %%
plt.figure(figsize=(4,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

# prepare data
x1 = list(exp2_R_1_alpah_05.tail(num_agents).query("decision == 0")['decision_th'])
y1 = list(exp2_R_1_alpah_05.tail(num_agents).query("decision == 0")['combined_info'])

x2 = list(exp2_R_1_alpah_05.tail(num_agents).query("decision == 1")['decision_th'])
y2 = list(exp2_R_1_alpah_05.tail(num_agents).query("decision == 1")['combined_info'])

# plot 
plt.scatter(x1, y1, marker='o', s = 30, alpha = 0.1, color="blue" ,label = "0")
plt.scatter(x2, y2, marker='o', s = 30, alpha = 0.1, color="red" ,label = "1")

plt.xlabel('Risk-tolerance threshold')
plt.ylabel('Risk Perception (opinions)')

# plt.xlim(0,1)
plt.ylim(0,1.02)
plt.show()

# %%
plt.figure(figsize=(4,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

# prepare data
x1 = list(exp2_R_1_alpah_0.tail(num_agents).query("decision == 0")['decision_th'])
y1 = list(exp2_R_1_alpah_0.tail(num_agents).query("decision == 0")['combined_info'])

x2 = list(exp2_R_1_alpah_0.tail(num_agents).query("decision == 1")['decision_th'])
y2 = list(exp2_R_1_alpah_0.tail(num_agents).query("decision == 1")['combined_info'])

# plot 
plt.scatter(x1, y1, marker='o', s = 30, alpha = 0.1, color="blue" ,label = "0")
plt.scatter(x2, y2, marker='o', s = 30, alpha = 0.1, color="red" ,label = "1")

plt.xlabel('Risk-tolerance threshold')
plt.ylabel('Risk Perception (opinions)')

# plt.xlim(0,1)
# plt.ylim(0,1.02)
plt.show()

# %% [markdown]
# ### observed mobility

# %%
plt.figure(figsize=(4,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

# prepare data
x1 = list(exp2_R_1_alpah_1.tail(num_agents).query("decision == 0")['decision_th'])
y1 = list(exp2_R_1_alpah_1.tail(num_agents).query("decision == 0")['observed_mobility'])

x2 = list(exp2_R_1_alpah_1.tail(num_agents).query("decision == 1")['decision_th'])
y2 = list(exp2_R_1_alpah_1.tail(num_agents).query("decision == 1")['observed_mobility'])

# plot 
plt.scatter(x1, y1, marker='o', s = 30, alpha = 0.1, color="blue" ,label = "0")
plt.scatter(x2, y2, marker='o', s = 30, alpha = 0.1, color="red" ,label = "1")

plt.xlabel('Risk-tolerance threshold')
plt.ylabel('Observed mobility')

# plt.xlim(0,1)
plt.ylim(-0.02,1.02)
plt.show()

# %%
plt.figure(figsize=(4,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

# prepare data
x1 = list(exp2_R_1_alpah_05.tail(num_agents).query("decision == 0")['decision_th'])
y1 = list(exp2_R_1_alpah_05.tail(num_agents).query("decision == 0")['observed_mobility'])

x2 = list(exp2_R_1_alpah_05.tail(num_agents).query("decision == 1")['decision_th'])
y2 = list(exp2_R_1_alpah_05.tail(num_agents).query("decision == 1")['observed_mobility'])

# plot 
plt.scatter(x1, y1, marker='o', s = 30, alpha = 0.1, color="blue" ,label = "0")
plt.scatter(x2, y2, marker='o', s = 30, alpha = 0.1, color="red" ,label = "1")

plt.xlabel('Risk-tolerance threshold')
plt.ylabel('Observed mobility')

# plt.xlim(0,1)
plt.ylim(-0.02,1.02)
plt.show()

# %%
plt.figure(figsize=(4,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

# prepare data
x1 = list(exp2_R_1_alpah_0.tail(num_agents).query("decision == 0")['decision_th'])
y1 = list(exp2_R_1_alpah_0.tail(num_agents).query("decision == 0")['combined_info'])

x2 = list(exp2_R_1_alpah_0.tail(num_agents).query("decision == 1")['decision_th'])
y2 = list(exp2_R_1_alpah_0.tail(num_agents).query("decision == 1")['combined_info'])

# plot 
plt.scatter(x1, y1, marker='o', s = 30, alpha = 0.1, color="blue" ,label = "0")
plt.scatter(x2, y2, marker='o', s = 30, alpha = 0.1, color="red" ,label = "1")

plt.xlabel('Risk-tolerance threshold')
plt.ylabel('Risk Perception (opinions)')

# plt.xlim(0,1)
# plt.ylim(0.02,1.02)
plt.show()

# %% [markdown]
# ## R = 0

# %%
exp2_R_0_alpah_0 = exp2_R_1_iter.query('alpha == 0 and R == 0')
exp2_R_0_alpah_02 = exp2_R_1_iter.query('alpha == 0.2 and R == 0')
exp2_R_0_alpah_05 = exp2_R_1_iter.query('alpha == 0.5 and R == 0')
exp2_R_0_alpah_08 = exp2_R_1_iter.query('alpha == 0.8 and R == 0')
exp2_R_0_alpah_1 = exp2_R_1_iter.query('alpha == 1 and R == 0')

# %% [markdown]
# ### risk perception

# %%
plt.figure(figsize=(4,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

# prepare data
x1 = list(exp2_R_0_alpah_1.tail(num_agents).query("decision == 0")['decision_th'])
y1 = list(exp2_R_0_alpah_1.tail(num_agents).query("decision == 0")['combined_info'])

x2 = list(exp2_R_0_alpah_1.tail(num_agents).query("decision == 1")['decision_th'])
y2 = list(exp2_R_0_alpah_1.tail(num_agents).query("decision == 1")['combined_info'])

# plot 
plt.scatter(x1, y1, marker='o', s = 30, alpha = 0.1, color="blue" ,label = "0")
plt.scatter(x2, y2, marker='o', s = 30, alpha = 0.1, color="red" ,label = "1")

plt.xlabel('Risk-tolerance threshold')
plt.ylabel('Risk Perception (opinions)')

# plt.xlim(0,1)
plt.ylim(-0.02,1.02)
plt.show()

# %%
plt.figure(figsize=(4,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

# prepare data
x1 = list(exp2_R_0_alpah_05.tail(num_agents).query("decision == 0")['decision_th'])
y1 = list(exp2_R_0_alpah_05.tail(num_agents).query("decision == 0")['combined_info'])

x2 = list(exp2_R_0_alpah_05.tail(num_agents).query("decision == 1")['decision_th'])
y2 = list(exp2_R_0_alpah_05.tail(num_agents).query("decision == 1")['combined_info'])

# plot 
plt.scatter(x1, y1, marker='o', s = 30, alpha = 0.1, color="blue" ,label = "0")
plt.scatter(x2, y2, marker='o', s = 30, alpha = 0.1, color="red" ,label = "1")

plt.xlabel('Risk-tolerance threshold')
plt.ylabel('Risk Perception (opinions)')

# plt.xlim(0,1)
plt.ylim(-0.02,1.02)
plt.show()

# %%
plt.figure(figsize=(4,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

# prepare data
x1 = list(exp2_R_0_alpah_0.tail(num_agents).query("decision == 0")['decision_th'])
y1 = list(exp2_R_0_alpah_0.tail(num_agents).query("decision == 0")['combined_info'])

x2 = list(exp2_R_0_alpah_0.tail(num_agents).query("decision == 1")['decision_th'])
y2 = list(exp2_R_0_alpah_0.tail(num_agents).query("decision == 1")['combined_info'])

# plot 
plt.scatter(x1, y1, marker='o', s = 30, alpha = 0.1, color="blue" ,label = "0")
plt.scatter(x2, y2, marker='o', s = 30, alpha = 0.1, color="red" ,label = "1")

plt.xlabel('Risk-tolerance threshold')
plt.ylabel('Risk Perception (opinions)')

# plt.xlim(0,1)
plt.ylim(-0.02,1.02)
plt.show()

# %% [markdown]
# ### observed mobility

# %%
plt.figure(figsize=(4,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

# prepare data
x1 = list(exp2_R_0_alpah_1.tail(num_agents).query("decision == 0")['decision_th'])
y1 = list(exp2_R_0_alpah_1.tail(num_agents).query("decision == 0")['observed_mobility'])

x2 = list(exp2_R_0_alpah_1.tail(num_agents).query("decision == 1")['decision_th'])
y2 = list(exp2_R_0_alpah_1.tail(num_agents).query("decision == 1")['observed_mobility'])

# plot 
plt.scatter(x1, y1, marker='o', s = 30, alpha = 0.1, color="blue" ,label = "0")
plt.scatter(x2, y2, marker='o', s = 30, alpha = 0.1, color="red" ,label = "1")

plt.xlabel('Risk-tolerance threshold')
plt.ylabel('Observed mobility')

# plt.xlim(0,1)
plt.ylim(-0.02,1.02)
plt.show()

# %%
plt.figure(figsize=(4,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

# prepare data
x1 = list(exp2_R_0_alpah_05.tail(num_agents).query("decision == 0")['decision_th'])
y1 = list(exp2_R_0_alpah_05.tail(num_agents).query("decision == 0")['observed_mobility'])

x2 = list(exp2_R_0_alpah_05.tail(num_agents).query("decision == 1")['decision_th'])
y2 = list(exp2_R_0_alpah_05.tail(num_agents).query("decision == 1")['observed_mobility'])

# plot 
plt.scatter(x1, y1, marker='o', s = 30, alpha = 0.1, color="blue" ,label = "0")
plt.scatter(x2, y2, marker='o', s = 30, alpha = 0.1, color="red" ,label = "1")

plt.xlabel('Risk-tolerance threshold')
plt.ylabel('Observed mobility')

# plt.xlim(0,1)
# plt.ylim(-0.02,1.02)
plt.show()

# %%
plt.figure(figsize=(4,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

# prepare data
x1 = list(exp2_R_0_alpah_0.tail(num_agents).query("decision == 0")['decision_th'])
y1 = list(exp2_R_0_alpah_0.tail(num_agents).query("decision == 0")['combined_info'])

x2 = list(exp2_R_0_alpah_0.tail(num_agents).query("decision == 1")['decision_th'])
y2 = list(exp2_R_0_alpah_0.tail(num_agents).query("decision == 1")['combined_info'])

# plot 
plt.scatter(x1, y1, marker='o', s = 30, alpha = 0.1, color="blue" ,label = "0")
plt.scatter(x2, y2, marker='o', s = 30, alpha = 0.1, color="red" ,label = "1")

plt.xlabel('Risk-tolerance threshold')
plt.ylabel('Risk Perception (opinions)')

# plt.xlim(0,1)
# plt.ylim(0.02,1.02)
plt.show()

# %% [markdown]
# ### 2. Peer trust (PT = low, mid, high)

# %%
exp2_PT_50_iter = pd.read_csv(results_folder+"/ex2_2_PT_batchrun_50_iteration.csv")

# %%
fig, axs = plt.subplots(1, 3, figsize=(9.5,2.75))

axs[0].set_title("Low PT")
axs[1].set_title("Mid PT")
axs[2].set_title("High PT")

axs[0].plot("Step" , "mobility_rate" , data = exp2_PT_50_iter.query('PT == "low" and alpha == 0').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0$") 
axs[0].plot("Step" , "mobility_rate" , data = exp2_PT_50_iter.query('PT == "low" and alpha == 0.2').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.2$") 
axs[0].plot("Step" , "mobility_rate" , data = exp2_PT_50_iter.query('PT == "low" and alpha == 0.5').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.5$")  
axs[0].plot("Step" , "mobility_rate" , data = exp2_PT_50_iter.query('PT == "low" and alpha == 0.8').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.8$") 
axs[0].plot("Step" , "mobility_rate" , data = exp2_PT_50_iter.query('PT == "low" and alpha == 1').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 1$") 

axs[1].plot("Step" , "mobility_rate" , data = exp2_PT_50_iter.query('PT == "mid" and alpha == 0').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0$") 
axs[1].plot("Step" , "mobility_rate" , data = exp2_PT_50_iter.query('PT == "mid" and alpha == 0.2').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.2$") 
axs[1].plot("Step" , "mobility_rate" , data = exp2_PT_50_iter.query('PT == "mid" and alpha == 0.5').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.5$")  
axs[1].plot("Step" , "mobility_rate" , data = exp2_PT_50_iter.query('PT == "mid" and alpha == 0.8').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.8$") 
axs[1].plot("Step" , "mobility_rate" , data = exp2_PT_50_iter.query('PT == "mid" and alpha == 1').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 1$") 

axs[2].plot("Step" , "mobility_rate" , data = exp2_PT_50_iter.query('PT == "high" and alpha == 0').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0$") 
axs[2].plot("Step" , "mobility_rate" , data = exp2_PT_50_iter.query('PT == "high" and alpha == 0.2').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.2$") 
axs[2].plot("Step" , "mobility_rate" , data = exp2_PT_50_iter.query('PT == "high" and alpha == 0.5').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.5$")  
axs[2].plot("Step" , "mobility_rate" , data = exp2_PT_50_iter.query('PT == "high" and alpha == 0.8').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.8$") 
axs[2].plot("Step" , "mobility_rate" , data = exp2_PT_50_iter.query('PT == "high" and alpha == 1').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 1$") 

for i in [0,1,2]:
    for pos in ['right', 'top', 'bottom', 'left']: 
        axs[i].spines[pos].set_visible(False)

    axs[i].set_ylim(-0.02,1.02)

axs[1].set_yticklabels([])
axs[2].set_yticklabels([])

axs[2].legend(ncol=1, bbox_to_anchor=(1, .87), loc = "best" ,fontsize = "small")

# X axis
fig.text(0.47, -0.01, 'Time step', ha='center')
# Y axis
fig.text(-0.01, 0.5, 'Mobility rate', va='center', rotation='vertical')


plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(4,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

sns.lineplot(x = "alpha" , y = "mobility_rate" , data = exp2_PT_50_iter.query('PT == "low" and Step == 100').groupby('alpha')['mobility_rate'].mean().reset_index(), label = 'Low PT') 
sns.lineplot(x = "alpha" , y = "mobility_rate" , data = exp2_PT_50_iter.query('PT == "mid" and Step == 100').groupby('alpha')['mobility_rate'].mean().reset_index(), label = 'Mid PT') 
sns.lineplot(x = "alpha" , y = "mobility_rate" , data = exp2_PT_50_iter.query('PT == "high" and Step == 100').groupby('alpha')['mobility_rate'].mean().reset_index(), label = 'High PT') 

sns.lineplot(x = "alpha" , y = "updated_decision_rate" , data = exp2_PT_50_iter.query('PT == "low" and Step == 100').groupby('alpha')['updated_decision_rate'].mean().reset_index(), label = "Low PT" , linestyle='--') 
sns.lineplot(x = "alpha" , y = "updated_decision_rate" , data = exp2_PT_50_iter.query('PT == "mid" and Step == 100').groupby('alpha')['updated_decision_rate'].mean().reset_index(), label = "Mid PT" , linestyle='--') 
sns.lineplot(x = "alpha" , y = "updated_decision_rate" , data = exp2_PT_50_iter.query('PT == "high" and Step == 100').groupby('alpha')['updated_decision_rate'].mean().reset_index(), label = "High PT" , linestyle='--') 

plt.ylim(-0.02,1)
plt.xlabel(r"$\alpha$")
plt.ylabel("")

plt.legend(bbox_to_anchor=(1, 0.79), ncol=1)

plt.show()

# %%
# plt.figure(figsize=(4,  3))
# for pos in ['right', 'top', 'bottom', 'left']: 
#     plt.gca().spines[pos].set_visible(False) 


# sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_PT_50_iter.query('PT == "low" and alpha == 0').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0$") 
# sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_PT_50_iter.query('PT == "low" and alpha == 0.2').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.2$") 
# sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_PT_50_iter.query('PT == "low" and alpha == 0.5').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.5$")  
# sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_PT_50_iter.query('PT == "low" and alpha == 0.8').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.8$") 
# sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_PT_50_iter.query('PT == "low" and alpha == 1').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 1$") 

# plt.ylim(0,1)
# plt.xlabel("Time step")
# plt.ylabel("Mobility rate")
# plt.legend(bbox_to_anchor=(1, .86), ncol=1)

# plt.show()

# %%
# plt.figure(figsize=(4,  3))
# for pos in ['right', 'top', 'bottom', 'left']: 
#     plt.gca().spines[pos].set_visible(False) 

# sns.lineplot(x = "alpha" , y = "mobility_rate" , data = exp2_PT_50_iter.query('PT == "low" and Step == 100').groupby('alpha')['mobility_rate'].mean().reset_index(), label = 'Mobility rate') 
# sns.lineplot(x = "alpha" , y = "updated_decision_rate" , data = exp2_PT_50_iter.query('PT == "low" and Step == 100').groupby('alpha')['updated_decision_rate'].mean().reset_index(), label = "Decision update rate") 

# plt.ylim(-0.02,1)
# plt.xlabel(r"$\alpha$")
# plt.ylabel("")

# # plt.legend(bbox_to_anchor=(1.7, 0.65), ncol=1)

# plt.show()

# %%
# plt.figure(figsize=(4,  3))
# for pos in ['right', 'top', 'bottom', 'left']: 
#     plt.gca().spines[pos].set_visible(False) 


# sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_PT_50_iter.query('PT == "mid" and alpha == 0').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0$") 
# sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_PT_50_iter.query('PT == "mid" and alpha == 0.2').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.2$") 
# sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_PT_50_iter.query('PT == "mid" and alpha == 0.5').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.5$")  
# sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_PT_50_iter.query('PT == "mid" and alpha == 0.8').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.8$") 
# sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_PT_50_iter.query('PT == "mid" and alpha == 1').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 1$") 

# plt.ylim(0,1)
# plt.xlabel("Time step")
# plt.ylabel("Mobility rate")
# plt.legend(bbox_to_anchor=(1, .86), ncol=1)

# plt.show()

# %%
# plt.figure(figsize=(4,  3))
# for pos in ['right', 'top', 'bottom', 'left']: 
#     plt.gca().spines[pos].set_visible(False) 

# sns.lineplot(x = "alpha" , y = "mobility_rate" , data = exp2_PT_50_iter.query('PT == "mid" and Step == 100').groupby('alpha')['mobility_rate'].mean().reset_index(), label = 'Mobility rate') 
# sns.lineplot(x = "alpha" , y = "updated_decision_rate" , data = exp2_PT_50_iter.query('PT == "mid" and Step == 100').groupby('alpha')['updated_decision_rate'].mean().reset_index(), label = "Decision update rate") 

# plt.ylim(-0.02,1)
# plt.xlabel(r"$\alpha$")
# plt.ylabel("")

# # plt.legend(bbox_to_anchor=(1.7, 0.65), ncol=1)

# plt.show()

# %%
# plt.figure(figsize=(4,  3))
# for pos in ['right', 'top', 'bottom', 'left']: 
#     plt.gca().spines[pos].set_visible(False) 


# sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_PT_50_iter.query('PT == "high" and alpha == 0').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0$") 
# sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_PT_50_iter.query('PT == "high" and alpha == 0.2').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.2$") 
# sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_PT_50_iter.query('PT == "high" and alpha == 0.5').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.5$")  
# sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_PT_50_iter.query('PT == "high" and alpha == 0.8').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.8$") 
# sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_PT_50_iter.query('PT == "high" and alpha == 1').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 1$") 

# plt.ylim(0,1)
# plt.xlabel("Time step")
# plt.ylabel("Mobility rate")
# plt.legend(bbox_to_anchor=(1, .86), ncol=1)

# plt.show()

# %%
# plt.figure(figsize=(4,  3))
# for pos in ['right', 'top', 'bottom', 'left']: 
#     plt.gca().spines[pos].set_visible(False) 

# sns.lineplot(x = "alpha" , y = "mobility_rate" , data = exp2_PT_50_iter.query('PT == "high" and Step == 100').groupby('alpha')['mobility_rate'].mean().reset_index(), label = 'Mobility rate') 
# sns.lineplot(x = "alpha" , y = "updated_decision_rate" , data = exp2_PT_50_iter.query('PT == "high" and Step == 100').groupby('alpha')['updated_decision_rate'].mean().reset_index(), label = "Decision update rate") 

# plt.ylim(-0.02,1)
# plt.xlabel(r"$\alpha$")
# plt.ylabel("")

# # plt.legend(bbox_to_anchor=(1.7, 0.65), ncol=1)

# plt.show()

# %% [markdown]
# ### 3. Tendency to share (B = low, mid, high)

# %%
exp2_B_50_iter = pd.read_csv(results_folder+"/ex2_3_B_batchrun_50_iteration.csv")

# %%
plt.figure(figsize=(4,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 


sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_B_50_iter.query('B == "low" and alpha == 0').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0$") 
sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_B_50_iter.query('B == "low" and alpha == 0.2').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.2$") 
sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_B_50_iter.query('B == "low" and alpha == 0.5').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.5$")  
sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_B_50_iter.query('B == "low" and alpha == 0.8').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.8$") 
sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_B_50_iter.query('B == "low" and alpha == 1').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 1$") 

plt.ylim(0,1)
plt.xlabel("Time step")
plt.ylabel("Mobility rate")
plt.legend(bbox_to_anchor=(1, .86), ncol=1)

plt.show()

# %%
plt.figure(figsize=(4,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

sns.lineplot(x = "alpha" , y = "mobility_rate" , data = exp2_B_50_iter.query('B == "low" and Step == 100').groupby('alpha')['mobility_rate'].mean().reset_index(), label = 'Mobility rate') 
sns.lineplot(x = "alpha" , y = "updated_decision_rate" , data = exp2_B_50_iter.query('B == "low" and Step == 100').groupby('alpha')['updated_decision_rate'].mean().reset_index(), label = "Decision update rate") 

plt.ylim(-0.02,1)
plt.xlabel(r"$\alpha$")
plt.ylabel("")

# plt.legend(bbox_to_anchor=(1.7, 0.65), ncol=1)

plt.show()

# %%
plt.figure(figsize=(4,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 


sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_B_50_iter.query('B == "mid" and alpha == 0').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0$") 
sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_B_50_iter.query('B == "mid" and alpha == 0.2').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.2$") 
sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_B_50_iter.query('B == "mid" and alpha == 0.5').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.5$")  
sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_B_50_iter.query('B == "mid" and alpha == 0.8').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.8$") 
sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_B_50_iter.query('B == "mid" and alpha == 1').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 1$") 

plt.ylim(0,1)
plt.xlabel("Time step")
plt.ylabel("Mobility rate")
plt.legend(bbox_to_anchor=(1, .86), ncol=1)

plt.show()

# %%
plt.figure(figsize=(4,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

sns.lineplot(x = "alpha" , y = "mobility_rate" , data = exp2_B_50_iter.query('B == "mid" and Step == 100').groupby('alpha')['mobility_rate'].mean().reset_index(), label = 'Mobility rate') 
sns.lineplot(x = "alpha" , y = "updated_decision_rate" , data = exp2_B_50_iter.query('B == "mid" and Step == 100').groupby('alpha')['updated_decision_rate'].mean().reset_index(), label = "Decision update rate") 

plt.ylim(-0.02,1)
plt.xlabel(r"$\alpha$")
plt.ylabel("")

# plt.legend(bbox_to_anchor=(1.7, 0.65), ncol=1)

plt.show()

# %%
plt.figure(figsize=(4,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 


sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_B_50_iter.query('B == "high" and alpha == 0').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0$") 
sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_B_50_iter.query('B == "high" and alpha == 0.2').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.2$") 
sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_B_50_iter.query('B == "high" and alpha == 0.5').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.5$")  
sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_B_50_iter.query('B == "high" and alpha == 0.8').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.8$") 
sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_B_50_iter.query('B == "high" and alpha == 1').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 1$") 

plt.ylim(0,1)
plt.xlabel("Time step")
plt.ylabel("Mobility rate")
plt.legend(bbox_to_anchor=(1, .86), ncol=1)

plt.show()

# %%
plt.figure(figsize=(4,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

sns.lineplot(x = "alpha" , y = "mobility_rate" , data = exp2_B_50_iter.query('B == "high" and Step == 100').groupby('alpha')['mobility_rate'].mean().reset_index(), label = 'Mobility rate') 
sns.lineplot(x = "alpha" , y = "updated_decision_rate" , data = exp2_B_50_iter.query('B == "high" and Step == 100').groupby('alpha')['updated_decision_rate'].mean().reset_index(), label = "Decision update rate") 

plt.ylim(-0.02,1)
plt.xlabel(r"$\alpha$")
plt.ylabel("")

# plt.legend(bbox_to_anchor=(1.7, 0.65), ncol=1)

plt.show()

# %% [markdown]
# ### 4. Risk-tolerance threshold (dt = low, mid, high)

# %%
exp2_dt_50_iter = pd.read_csv(results_folder+"/ex2_4_dt_batchrun_50_iteration.csv")

# %%
plt.figure(figsize=(4,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 


sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_dt_50_iter.query('dt == "low" and alpha == 0').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0$") 
sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_dt_50_iter.query('dt == "low" and alpha == 0.2').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.2$") 
sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_dt_50_iter.query('dt == "low" and alpha == 0.5').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.5$")  
sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_dt_50_iter.query('dt == "low" and alpha == 0.8').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.8$") 
sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_dt_50_iter.query('dt == "low" and alpha == 1').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 1$") 

plt.ylim(0,1)
plt.xlabel("Time step")
plt.ylabel("Mobility rate")
plt.legend(bbox_to_anchor=(1, .86), ncol=1)

plt.show()

# %%
plt.figure(figsize=(4,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

sns.lineplot(x = "alpha" , y = "mobility_rate" , data = exp2_dt_50_iter.query('dt == "low" and Step == 100').groupby('alpha')['mobility_rate'].mean().reset_index(), label = 'Mobility rate') 
sns.lineplot(x = "alpha" , y = "updated_decision_rate" , data = exp2_dt_50_iter.query('dt == "low" and Step == 100').groupby('alpha')['updated_decision_rate'].mean().reset_index(), label = "Decision update rate") 

plt.ylim(-0.02,1)
plt.xlabel(r"$\alpha$")
plt.ylabel("")

# plt.legend(bbox_to_anchor=(1.7, 0.65), ncol=1)

plt.show()

# %%
plt.figure(figsize=(4,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 


sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_dt_50_iter.query('dt == "mid" and alpha == 0').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0$") 
sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_dt_50_iter.query('dt == "mid" and alpha == 0.2').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.2$") 
sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_dt_50_iter.query('dt == "mid" and alpha == 0.5').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.5$")  
sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_dt_50_iter.query('dt == "mid" and alpha == 0.8').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.8$") 
sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_dt_50_iter.query('dt == "mid" and alpha == 1').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 1$") 

plt.ylim(0,1)
plt.xlabel("Time step")
plt.ylabel("Mobility rate")
plt.legend(bbox_to_anchor=(1, .86), ncol=1)

plt.show()

# %%
plt.figure(figsize=(4,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

sns.lineplot(x = "alpha" , y = "mobility_rate" , data = exp2_dt_50_iter.query('dt == "mid" and Step == 100').groupby('alpha')['mobility_rate'].mean().reset_index(), label = 'Mobility rate') 
sns.lineplot(x = "alpha" , y = "updated_decision_rate" , data = exp2_dt_50_iter.query('dt == "mid" and Step == 100').groupby('alpha')['updated_decision_rate'].mean().reset_index(), label = "Decision update rate") 

plt.ylim(-0.02,1)
plt.xlabel(r"$\alpha$")
plt.ylabel("")

# plt.legend(bbox_to_anchor=(1.7, 0.65), ncol=1)

plt.show()

# %%
plt.figure(figsize=(4,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 


sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_dt_50_iter.query('dt == "high" and alpha == 0').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0$") 
sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_dt_50_iter.query('dt == "high" and alpha == 0.2').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.2$") 
sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_dt_50_iter.query('dt == "high" and alpha == 0.5').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.5$")  
sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_dt_50_iter.query('dt == "high" and alpha == 0.8').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 0.8$") 
sns.lineplot(x = "Step" , y = "mobility_rate" , data = exp2_dt_50_iter.query('dt == "high" and alpha == 1').groupby("Step")['mobility_rate'].mean().reset_index() , label = r"$\alpha = 1$") 

plt.ylim(0,1)
plt.xlabel("Time step")
plt.ylabel("Mobility rate")
plt.legend(bbox_to_anchor=(1, .86), ncol=1)

plt.show()

# %%
plt.figure(figsize=(4,  3))
for pos in ['right', 'top', 'bottom', 'left']: 
    plt.gca().spines[pos].set_visible(False) 

sns.lineplot(x = "alpha" , y = "mobility_rate" , data = exp2_dt_50_iter.query('dt == "high" and Step == 100').groupby('alpha')['mobility_rate'].mean().reset_index(), label = 'Mobility rate') 
sns.lineplot(x = "alpha" , y = "updated_decision_rate" , data = exp2_dt_50_iter.query('dt == "high" and Step == 100').groupby('alpha')['updated_decision_rate'].mean().reset_index(), label = "Decision update rate") 

plt.ylim(-0.02,1)
plt.xlabel(r"$\alpha$")
plt.ylabel("")

# plt.legend(bbox_to_anchor=(1.7, 0.65), ncol=1)

plt.show()
